# %% [markdown]
# ## <b> Evaluation Project 7 Flight Price Prediction </b>
# <b><em> By: Mr.Lokesh Baviskar </em></b>
#
# <b><em> Batch: 1833 </em></b>

# %% [markdown]
# ## <b> PROBLEM STATEMENT :</b>
#
# <b><em>Flight ticket prices can be something hard to guess, today we might see a price, check out the price of the same flight tomorrow, it will be a different story. We might have often heard travellers saying that flight ticket prices are so unpredictable. Here you will be provided with prices of flight tickets for various airlines between the months of March and June of 2019 and between various cities.
#
# Size of training set: 10683 records
#
# Size of test set: 2671 records
#     </em></b>

# %% [markdown]
# #### FEATURES:
#
# **Airline:** The name of the airline.
#
# **Date_of_Journey:** The date of the journey
#
# **Source:** The source from which the service begins.
#
# **Destination:** The destination where the service ends.
#
# **Route:** The route taken by the flight to reach the destination.
#
# **Dep_Time:** The time when the journey starts from the source.
#
# **Arrival_Time:** Time of arrival at the destination.
#
# **Duration:** Total duration of the flight.
#
# **Total_Stops:** Total stops between the source and destination.
#
# **Additional_Info:** Additional information about the flight
#
# **Price:** The price of the ticket

# %% [markdown]
# #### You have to use your skills as a data scientist and build a machine learning model to predict the price of the flight ticket.

# %% [markdown]
# <b><em>Note: You can find the dataset in the link below.
#
# Downlaod Files:</em></b>
#
# https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects

# %% [markdown]
# - <b> Importing require library for performing EDA, Data Wrangling and data cleaning</b>

# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
# Importing Flight Prediction dataset Excel file using pandas
df = pd.read_excel('Data_Train.xlsx')

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
df.head()
# Out:
# No of Rows: 10683
# No of Columns: 11
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# Sort columns by datatypes
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Price'], object: ['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route', 'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops', 'Additional_Info']}

# %% [markdown]
# #### Comment :
# - Training dataset contain 10683 rows and 11 columns.
# - Our Target variable is **Price**. We gone predict flight prices using **Various Regression Algorithms.**
# - Some feature with date and time related columns are mention with object datatype. **We gone convert them into datetime datatype format along with going to perform some feature engineering over them to create few new columns of our interest.**

# %% [markdown]
#  **Converting Date and time columns from object type to Datetime type**

# %%
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'])
df['Dep_Time'] = pd.to_datetime(df['Dep_Time'])
df['Arrival_Time']=pd.to_datetime(df['Arrival_Time'])

# %% [markdown]
# #### Details of Feature engineering operation over various datetime datatype feature
# - **We know that flight price vary according to season,demand and festival offer like new year, diwali. Considering this Date of joureny is seem like important feature affecting variation of flight price.**
# - From excel file we know that all data belong to 2019. So year doesnot matter.
# - We gone split Date of journey into date and month columns.
# - **Conversion of duration column into new columns represnting duration in min.**
# - Extracting Hour and minutes from Dep_Time and Arrival Time columns.

# %% [markdown]
# **1. Feature Engineering on Date of Journey Columns**

# %%
# Extracting Day from Date_of_journey column
df['Journey_Day'] = pd.to_datetime(df.Date_of_Journey,format="%d/%m/%Y").dt.day

# Extracting Month from Date_of_journey column
df['Journey_Month'] = pd.to_datetime(df.Date_of_Journey, format="%d/%m/%Y").dt.month

# Dropping Date_of_journey column
df.drop("Date_of_Journey",axis=1,inplace=True)

# %% [markdown]
# **2. Feature Engineering on 'Duration' Column**

# %%
# Conversion of Duration column from hr & Minutes format to Minutes
df['Duration']=df['Duration'].str.replace('h','*60').str.replace(' ','+').str.replace('m','*1').apply(eval)

# convert this column into a numeric datatypes
df['Duration']=pd.to_numeric(df['Duration'])

# %% [markdown]
# **3. Feature Engineering on 'Dep_Time' Column**

# %%
# Extracting Hours from Dep_Time column
df['Dep_Hour']=pd.to_datetime(df['Dep_Time']).dt.hour

# Extracting Minutes from Dep_Time column
df['Dep_Min']=pd.to_datetime(df['Dep_Time']).dt.minute

# Dropping Dep_Time column
df.drop("Dep_Time",axis=1,inplace=True)

# %% [markdown]
# **4. Feature Engineering on 'Arrival_Time' Column**

# %%
# Extracting Arrival_Hour from Arrival_Time column
df['Arrival_Hour']=pd.to_datetime(df['Arrival_Time']).dt.hour

# Extracting Arrival_Min from Arrival_Time column
df['Arrival_Min']=pd.to_datetime(df['Arrival_Time']).dt.minute

# Dropping Arruval_Time column
df.drop("Arrival_Time",axis=1,inplace=True)

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
df.head()
# Out:
# No of Rows: 10683
# No of Columns: 14
#        Airline    Source Destination                  Route  Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL       170
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR       445
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      1140
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR       325
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL       285
#
#   Total_Stops Additional_Info  Price  Journey_Day  Journey_Month  Dep_Hour  \
# 0    non-stop         No info   3897           24              3        22
# 1     2 stops         No info   7662            5              1         5
# 2     2 stops         No info  13882            6              9         9
# 3      1 stop         No info   6218            5             12        18
# 4      1 stop         No info  13302            3              1        16
#
#    Dep_Min  Arrival_Hour  Arrival_Min
# 0       20             1           10
# 1       50            13           15
# 2       25             4           25
# 3        5            23           30
# 4       50            21           35

# %%
# Sort columns by datatypes
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Duration', 'Price', 'Journey_Day', 'Journey_Month', 'Dep_Hour', 'Dep_Min', 'Arrival_Hour', 'Arrival_Min'], object: ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']}

# %%
# Spliting data into categorical and Numerical Variable
Numerical = ['Duration', 'Price', 'Journey_Day', 'Journey_Month', 'Dep_Hour', 'Dep_Min', 'Arrival_Hour', 'Arrival_Min']

Categorical = ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info']

# %% [markdown]
# #### We also need to do some feature engineering on Source and Destination columns, We can see at some place Dehli is mention and other places New Dehli is mention.
# #### First enlist different unique values in categorical variable and afterwards we will perform feature engineering.

# %%
for i in Categorical:
    print('Unique value counts of ',i, 'Enlisted as Below Table :')
    print('-'*40)
    print(df[i].value_counts())
    print("*"*120)
# Out:
# Unique value counts of  Airline Enlisted as Below Table :
# ----------------------------------------
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64
# ************************************************************************************************************************
# Unique value counts of  Source Enlisted as Below Table :
# ----------------------------------------
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64
# ************************************************************************************************************************
# Unique value counts of  Destination Enlisted as Below Table :
# ----------------------------------------
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64
# ************************************************************************************************************************
# Unique value counts of  Route Enlisted as Below Table :
# ----------------------------------------
# DEL → BOM → COK                2376
# BLR → DEL                      1552
# CCU → BOM → BLR                 979
# CCU → BLR                       724
# BOM → HYD                       621
#                                ...
# BOM → JDH → JAI → DEL → HYD       1
# BLR → HBX → BOM → NAG → DEL       1
# BOM → JLR → HYD                   1
# BOM → RPR → VTZ → HYD             1
# CCU → IXA → BLR                   1
# Name: Route, Length: 128, dtype: int64
# ************************************************************************************************************************
# Unique value counts of  Total_Stops Enlisted as Below Table :
# ----------------------------------------
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64
# ************************************************************************************************************************
# Unique value counts of  Additional_Info Enlisted as Below Table :
# ----------------------------------------
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# Red-eye flight                     1
# 1 Short layover                    1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64
# ************************************************************************************************************************

# %% [markdown]
# #### Observation :
# - "New Delhi" is mention as "Delhi". We we gone regulated it.
# - No info is mention as 'No Info' few times.
# - **Very Few Premium economy or Business class flight in dataset. This might be due to high ticket price**

# %%
# Replacing "New Delhi" as "Delhi" in Destination column
df["Destination"] = df["Destination"].replace("New Delhi","Delhi")

# In the column "Additional Info", "No Info" and "No info" are same so replacing it by "No Info
df['Additional_Info'] = df['Additional_Info'].replace("No info", "No Info")

# %% [markdown]
# ### Data Integrity Check

# %% [markdown]
# <b> Since dataset is large, Let check for any entry which is repeated or duplicated in dataset. </b>

# %%
df.duplicated().sum()  # This will check the duplicate data for all columns.
# Out:
# 222

# %%
df.duplicated().max()
# Out:
# True

# %% [markdown]
# **Around 222 duplicate data rows. It huge and we gone drop them. There is no point on training model on duplicated data.**

# %%
df.drop_duplicates(keep='last',inplace= True)

# %%
df.shape
# Out:
# (10461, 14)

# %% [markdown]
# <b> Let check if any whitespace, 'NA' or '-' exist in dataset. </b>

# %%
df.isin([' ','NA','-','?']).sum().any()
# Out:
# False

# %% [markdown]
# ### Missing value check

# %%
#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                  Missing Values  % Missing data
# Total_Stops                   1        0.009559
# Route                         1        0.009559
# Arrival_Min                   0        0.000000
# Arrival_Hour                  0        0.000000
# Dep_Min                       0        0.000000
# Dep_Hour                      0        0.000000
# Journey_Month                 0        0.000000
# Journey_Day                   0        0.000000
# Price                         0        0.000000
# Additional_Info               0        0.000000
# Duration                      0        0.000000
# Destination                   0        0.000000
# Source                        0        0.000000
# Airline                       0        0.000000

# %% [markdown]
# ** Missing values are present in Total Stops and Route. These variable are categorical in nature, we gone impute them with mode.**

# %%
# Checking the mode of Categorical columns "Route" 
print("The mode of Route is:",df["Route"].mode())

# Filling the missing values in "Route" withs its mode
df['Route'] = df['Route'].fillna(df['Route'].mode()[0])

# Checking the mode of Categorical columns "Total_Stops"
print("The mode of Total_Stops is:",df["Total_Stops"].mode())

# Filling the mising values in "Total_Stops" by its mode
df['Total_Stops']=df['Total_Stops'].fillna(df['Total_Stops'].mode()[0])
# Out:
# The mode of Route is: 0    DEL → BOM → COK
# dtype: object
# The mode of Total_Stops is: 0    1 stop
# dtype: object

# %% [markdown]
# #### Missing value check after imputation

# %%
# Heatmap of missing value
sns.heatmap(df.isnull(),cmap="gist_earth")
plt.show()

# %% [markdown]
# #### Comment :
# <b> Finally, No Missing Value and duplicate entry is Present.
#
# We are Now Yes To Go Further !!!</b>

# %% [markdown]
# ### Statistical Matrix

# %%
df.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style  type="text/css" >
# #T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col0,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col0,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col0,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col1,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col2,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col5,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col0,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col1,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col2,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col5,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col0,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col1,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col2,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col5,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row5_col0,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row5_col1,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row5_col2,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row5_col5,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row6_col0,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row6_col1,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row6_col2,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row6_col5,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row7_col0,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row7_col1,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row7_col2,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row7_col5{
#             background-color:  #fff7f3;
#             color:  #000000;
#         }#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col1{
#             background-color:  #feebe7;
#             color:  #000000;
#         }#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col2{
#             background-color:  #fde4e0;
#             color:  #000000;
#         }#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col5{
#             background-color:  #feece9;
#             color:  #000000;
#         }#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col1,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col2,#T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col5{
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }</style><table id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7level0_row0" class="row_heading level0 row0" >Duration</th>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col0" class="data row0 col0" >10461.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col1" class="data row0 col1" >629.945034</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col2" class="data row0 col2" >500.742197</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col3" class="data row0 col3" >5.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col4" class="data row0 col4" >170.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col5" class="data row0 col5" >505.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col6" class="data row0 col6" >910.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row0_col7" class="data row0 col7" >2860.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7level0_row1" class="row_heading level0 row1" >Price</th>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col0" class="data row1 col0" >10461.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col1" class="data row1 col1" >9027.212504</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col2" class="data row1 col2" >4624.861032</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col3" class="data row1 col3" >1759.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col4" class="data row1 col4" >5224.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col5" class="data row1 col5" >8266.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col6" class="data row1 col6" >12346.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row1_col7" class="data row1 col7" >79512.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7level0_row2" class="row_heading level0 row2" >Journey_Day</th>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col0" class="data row2 col0" >10461.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col1" class="data row2 col1" >12.629194</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col2" class="data row2 col2" >8.791165</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col3" class="data row2 col3" >3.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col4" class="data row2 col4" >5.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col5" class="data row2 col5" >6.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col6" class="data row2 col6" >21.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row2_col7" class="data row2 col7" >27.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7level0_row3" class="row_heading level0 row3" >Journey_Month</th>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col0" class="data row3 col0" >10461.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col1" class="data row3 col1" >5.535130</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col2" class="data row3 col2" >2.995285</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col4" class="data row3 col4" >3.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col5" class="data row3 col5" >5.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col6" class="data row3 col6" >6.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row3_col7" class="data row3 col7" >12.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7level0_row4" class="row_heading level0 row4" >Dep_Hour</th>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col0" class="data row4 col0" >10461.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col1" class="data row4 col1" >12.476341</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col2" class="data row4 col2" >5.726072</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col4" class="data row4 col4" >8.000000</td>
#                         <td id="T_f3d257a8_437f_11ec_92a8_e4029bad80b7row4_col5" class="data row4 col5" >11.000000</td>
#                         <td id="T_f3d257a8_43

# %%
df[Categorical].describe().T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# </style><table id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >unique</th>        <th class="col_heading level0 col2" >top</th>        <th class="col_heading level0 col3" >freq</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7level0_row0" class="row_heading level0 row0" >Airline</th>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row0_col0" class="data row0 col0" >10461</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row0_col1" class="data row0 col1" >12</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row0_col2" class="data row0 col2" >Jet Airways</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row0_col3" class="data row0 col3" >3700</td>
#             </tr>
#             <tr>
#                         <th id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7level0_row1" class="row_heading level0 row1" >Source</th>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row1_col0" class="data row1 col0" >10461</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row1_col1" class="data row1 col1" >5</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row1_col2" class="data row1 col2" >Delhi</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row1_col3" class="data row1 col3" >4346</td>
#             </tr>
#             <tr>
#                         <th id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7level0_row2" class="row_heading level0 row2" >Destination</th>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row2_col0" class="data row2 col0" >10461</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row2_col1" class="data row2 col1" >5</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row2_col2" class="data row2 col2" >Cochin</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row2_col3" class="data row2 col3" >4346</td>
#             </tr>
#             <tr>
#                         <th id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7level0_row3" class="row_heading level0 row3" >Route</th>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row3_col0" class="data row3 col0" >10461</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row3_col1" class="data row3 col1" >128</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row3_col2" class="data row3 col2" >DEL → BOM → COK</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row3_col3" class="data row3 col3" >2377</td>
#             </tr>
#             <tr>
#                         <th id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7level0_row4" class="row_heading level0 row4" >Total_Stops</th>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row4_col0" class="data row4 col0" >10461</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row4_col1" class="data row4 col1" >5</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row4_col2" class="data row4 col2" >1 stop</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row4_col3" class="data row4 col3" >5626</td>
#             </tr>
#             <tr>
#                         <th id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7level0_row5" class="row_heading level0 row5" >Additional_Info</th>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row5_col0" class="data row5 col0" >10461</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row5_col1" class="data row5 col1" >9</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row5_col2" class="data row5 col2" >No Info</td>
#                         <td id="T_03b3edf0_4380_11ec_98f4_e4029bad80b7row5_col3" class="data row5 col3" >8184</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Observation :
# - The Minimum flight ticket price is Rs.1759 and Maximum flight ticket price is Rs.79512.
# - The ( mean > median ) for Price,Journey_Day,Duration and Dep_Hour, <u>which mean right skew data.</u>
# - The ( mean < median ) for Dep_Min,Arrival_Hour and Arrival_Min <u>which mean left skew data.</u>
# - **Presense of outliers in Duration & Price columns as we see huge difference in 75% and max.**
# - High value of std. deviation indicating spread of data.
# - There are 12 airline in dataset with **maximum flight run by Jet Airways.**
# - The data of 128 route in dataset and we find **maximum flight on route DEL → BOM → COK.**
# - Long route flight have atleast one 1 stop.

# %% [markdown]
# ## Exploring Features Source

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Source'].value_counts().plot.pie(explode=[0.03,0.03,0.03,0.03,0.03],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Flight Distribution Source wise', fontsize=22,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Source',data=df,ax=ax[1])
ax[1].set_title('Source Distribution',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Source",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Observation :
# - **Maximum flight depart from Delhi followed by Kolkata.**
#
# #### Let Explore Source With respect to Target Variable

# %%
# Source vs Average Price
plt.figure(figsize=(12,7))
sns.catplot(y='Price',x='Source',data= df.sort_values('Price',ascending=False),kind="boxen",height=6, aspect=2)
plt.show()

# %% [markdown]
# **Based upon Source location Maximum Fare Comes for Banglore flight.**

# %% [markdown]
# ## Destination VS Price

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Destination'].value_counts().plot.pie(explode=[0.03,0.03,0.03,0.03,0.03],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Flight Distribution Destination wise', fontsize=22,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Destination',data=df,ax=ax[1])
ax[1].set_title('Destination Distribution',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Destination",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# **Maximum 41.5% Flight lands into cochin followed by Banglore.**

# %%
# Destination vs AveragePrice
sns.catplot(y='Price',x='Destination',data= df.sort_values('Price',ascending=False),
            kind = "boxen",height = 7, aspect = 2 )
plt.show()

# %% [markdown]
# **The Flight ticket price range in Delhi is the maximum, reason may be traffic & the National Capital, political seat of power and a highly visited place for vacations(same for bangalore & cochin)**

# %% [markdown]
# ### Airlines VS Source

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Duration  \
# 0       IndiGo  Banglore       Delhi              BLR → DEL       170
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR       445
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      1140
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR       325
# 4       IndiGo  Banglore       Delhi        BLR → NAG → DEL       285
#
#   Total_Stops Additional_Info  Price  Journey_Day  Journey_Month  Dep_Hour  \
# 0    non-stop         No Info   3897           24              3        22
# 1     2 stops         No Info   7662            5              1         5
# 2     2 stops         No Info  13882            6              9         9
# 3      1 stop         No Info   6218            5             12        18
# 4      1 stop         No Info  13302            3              1        16
#
#    Dep_Min  Arrival_Hour  Arrival_Min
# 0       20             1           10
# 1       50            13           15
# 2       25             4           25
# 3        5            23           30
# 4       50            21           35

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(df['Airline'],  palette='hsv')
plt.title('Flight distribution as per Airline', fontsize=22, fontweight='bold')
plt.xlabel('Airline', fontsize=18,fontweight='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation=90)
plt.yticks(fontsize=16,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Comment :
# - jet airways Airline runs highest number of flights out of all flights.
# - **Very Few Premium class flights.**
# #### Let Visualise Price according to these Airline

# %%
# Airline vs AveragePrice
sns.catplot(y='Price',x='Airline',data= df.sort_values('Price',ascending=False),
            kind="boxen",height=6, aspect=3)
plt.title("Variation AirFare as per Airline",fontsize=20, fontweight='bold')
plt.xlabel('Airline', fontsize=18,fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=16,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observation:
# - Full service airlines Jet airways and Air India are always highly priced due to various amenities they provide.
# - Low-cost carriers like indigo and spicejet have a lower and similar fare range

# %% [markdown]
# ## Duration VS Price

# %%
#duration v/s AveragePrice
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Duration', y='Price')
plt.title("Checking how price changes based on Duration",fontsize=18, fontweight='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.yticks(fontsize=16,fontweight ='bold')
plt.show()

# %% [markdown]
# **We know that duration( or distance) plays a major role in affecting air ticket prices but we see no such pattern here, as there must be there are other significant factors affecting air fare like type of airline, destination of flight, date of journey of flight(higher if collides with a public holiday)**

# %% [markdown]
# ### Total Stops VS Price

# %%
plt.figure(figsize=(8,6))
sns.barplot(df["Total_Stops"],df["Price"],data=df,palette="ch:.28")
plt.title("Checking how price changes based on Stops",fontsize=20, fontweight='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.yticks(fontsize=16,fontweight ='bold')
plt.show()

# %% [markdown]
# **As a direct/non-stop flight is accounting for fare of only one flight for a trip, its average fair is the least. As the no. of stops/layovers increase, the fare price goes up accounting for no. of flights and due to other resources being used up for the same.**

# %%
fig, axes = plt.subplots(2,2,figsize=(18,15))

# Checking relation between Journey_Day and Price
sns.boxenplot(x='Journey_Day',y='Price',ax = axes[0,0],data=df)

# Checking relation between Journey_Mionth and Price
sns.barplot(x='Journey_Month',y='Price',ax = axes[0,1],data=df,palette='plasma')

# Checking relation between Dep_Min and Price
sns.boxplot(x='Dep_Min',y='Price',ax=axes[1,0],data=df,palette='husl')

# Checking relation between Dep_Hour and Price
sns.barplot(x='Dep_Hour',y='Price',ax=axes[1,1],data=df,palette="bright")
plt.show()

# %% [markdown]
# #### Observation :
# - Airfare is high on Day 3 followed by Day 18.
# - January month are most expensive than others while airfare least expensive in April month.

# %% [markdown]
# # Encoding categorical data

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Categorical:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Airline  Source  Destination  Route  Duration  Total_Stops  \
# 0        3       0            2     18       170            4
# 1        1       3            0     84       445            1
# 2        4       2            1    118      1140            1
# 3        3       3            0     91       325            0
# 4        3       0            2     29       285            0
#
#    Additional_Info  Price  Journey_Day  Journey_Month  Dep_Hour  Dep_Min  \
# 0                6   3897           24              3        22       20
# 1                6   7662            5              1         5       50
# 2                6  13882            6              9         9       25
# 3                6   6218            5             12        18        5
# 4                6  13302            3              1        16       50
#
#    Arrival_Hour  Arrival_Min
# 0             1           10
# 1            13           15
# 2             4           25
# 3            23           30
# 4            21           35

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int32: ['Airline', 'Source', 'Destination', 'Route', 'Total_Stops', 'Additional_Info'], int64: ['Duration', 'Price', 'Journey_Day', 'Journey_Month', 'Dep_Hour', 'Dep_Min', 'Arrival_Hour', 'Arrival_Min']}

# %% [markdown]
# # Feature selection and Engineering

# %% [markdown]
# ## 1. Outliers Detection and Removal

# %%
plt.figure(figsize=(18,10),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# <b> From Boxplot we can see outliers exist dataset.</b>

# %% [markdown]
# ### Outliers removal using Zscore method

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (10461, 14)
# Shape of the dataframe after removing outliers:  (10289, 14)
# Percentage of data loss post outlier removal:  1.6442022751171015

# %% [markdown]
# ## 2. Skewness of features

# %%
plt.figure(figsize=(20,10),facecolor='white')
sns.set_palette('gnuplot')
plotnum=1
for col in Numerical:
    if plotnum<=6:
        plt.subplot(2,3,plotnum)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# **Skewness is important feature for continous data.**
# **There is no relevence of skweness for discrete numerical feature like month and categorical feature.So we gone ignore skewness present in discrete numerical and categorical feature.**

# %% [markdown]
# **We also going to ignore sknewness in target feature.**

# %%
df.skew()
# Out:
# Airline            0.721810
# Source            -0.436014
# Destination        0.850689
# Route             -0.487883
# Duration           0.820318
# Total_Stops        0.599846
# Additional_Info   -0.726010
# Price              0.442553
# Journey_Day        0.361840
# Journey_Month      0.636388
# Dep_Hour           0.099829
# Dep_Min            0.176249
# Arrival_Hour      -0.371973
# Arrival_Min        0.107114
# dtype: float64

# %% [markdown]
# **Price and duration are continous numerical data with skewed nature. Out of which Price is target variable, so ingore it.**
#
# **We gone transform duration. For rest others we gone ignore skewness present as they discrete numerical and categorical feature**

# %%
df['Duration'] = np.log1p(df['Duration'])

# %% [markdown]
# #### Checking skewness after transformation.

# %%
df['Duration'].skew()
# Out:
# -0.14885157403409577

# %% [markdown]
# ## 3. Corrleation

# %%
df.corr()
# Out:
#                   Airline    Source  Destination     Route  Duration  \
# Airline          1.000000 -0.015504     0.071028  0.029372 -0.115570
# Source          -0.015504  1.000000    -0.430431  0.390544  0.128243
# Destination      0.071028 -0.430431     1.000000 -0.219421 -0.519574
# Route            0.029372  0.390544    -0.219421  1.000000  0.368942
# Duration        -0.115570  0.128243    -0.519574  0.368942  1.000000
# Total_Stops      0.034367 -0.235253     0.517818 -0.454621 -0.817248
# Additional_Info  0.100328 -0.035504     0.132394 -0.004211 -0.277367
# Price           -0.037164  0.077542    -0.334660  0.245817  0.672463
# Journey_Day      0.030017 -0.005684     0.016181  0.081385 -0.044900
# Journey_Month   -0.012245  0.041855    -0.061807  0.019817  0.080802
# Dep_Hour        -0.039750  0.061320    -0.090543 -0.072813 -0.004032
# Dep_Min         -0.063211 -0.049390     0.094539 -0.062484 -0.038597
# Arrival_Hour     0.001202  0.028036    -0.062342  0.020383  0.067942
# Arrival_Min     -0.075916  0.020829     0.006426 -0.179203 -0.127676
#
#                  Total_Stops  Additional_Info     Price  Journey_Day  \
# Airline             0.034367         0.100328 -0.037164     0.030017
# Source             -0.235253        -0.035504  0.077542    -0.005684
# Destination         0.517818         0.132394 -0.334660     0.016181
# Route              -0.454621        -0.004211  0.245817     0.081385
# Duration           -0.817248        -0.277367  0.672463    -0.044900
# Total_Stops         1.000000         0.263522 -0.626234     0.038820
# Additional_Info     0.263522         1.000000 -0.155222    -0.006106
# Price              -0.626234        -0.155222  1.000000    -0.146315
# Journey_Day         0.038820        -0.006106 -0.146315     1.000000
# Journey_Month      -0.065168        -0.041823  0.072558    -0.282914
# Dep_Hour            0.038382        -0.063337  0.011200    -0.009465
# Dep_Min             0.053461         0.028095 -0.055109    -0.010120
# Arrival_Hour       -0.100318        -0.025678  0.042929    -0.001491
# Arrival_Min         0.178777         0.044119 -0.102230    -0.019360
#
#                  Journey_Month  Dep_Hour   Dep_Min  Arrival_Hour  Arrival_Min
# Airline              -0.012245 -0.039750 -0.063211      0.001202    -0.075916
# Source                0.041855  0.061320 -0.049390      0.028036     0.020829
# Destination          -0.061807 -0.090543  0.094539     -0.062342     0.006426
# Route                 0.019817 -0.072813 -0.062484      0.020383    -0.179203
# Duration              0.080802 -0.004032 -0.038597      0.067942    -0.127676
# Total_Stops          -0.065168  0.038382  0.053461     -0.100318     0.178777
# Additional_Info      -0.041823 -0.063337  0.028095     -0.025678     0.044119
# Price                 0.072558  0.011200 -0.055109      0.042929    -0.102230
# Journey_Day          -0.282914 -0.009465 -0.010120     -0.001491    -0.019360
# Journey_Month         1.000000  0.027182  0.009782     -0.002404    -0.023438
# Dep_Hour              0.027182  1.000000 -0.016565      0.005543     0.074315
# Dep_Min               0.009782 -0.016565  1.000000      0.048983    -0.021658
# Arrival_Hour         -0.002404  0.005543  0.048983      1.000000    -0.152517
# Arrival_Min          -0.023438  0.074315 -0.021658     -0.152517     1.000000

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df.corr()['Price'].drop(['Price']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15,fontweight='bold')
plt.ylabel('Price',fontsize=15,fontweight='bold')
plt.title('Correlation of features with Target Variable Price',fontsize = 20,fontweight='bold')
plt.show()

# %% [markdown]
# **Total stops and duration are correlated with Target varible with correlation coeffient of 0.6 & more.**
#
# **Maximum correlation in dataset exist between Duration & total stops. They are negatively correlated with each other.**

# %% [markdown]
# ## Standard Scaling

# %%
# Splitting data in target and dependent feature
X = df.drop(['Price'], axis =1)
Y = df['Price']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
#  ## 5. Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(X_scale,i) for i in range(len(X.columns))]
vif["Features"] = X.columns
vif
# Out:
#     VIF values         Features
# 0     1.046279          Airline
# 1     1.506367           Source
# 2     1.789798      Destination
# 3     1.555181            Route
# 4     3.420045         Duration
# 5     3.558776      Total_Stops
# 6     1.126826  Additional_Info
# 7     1.106882      Journey_Day
# 8     1.096836    Journey_Month
# 9     1.033988         Dep_Hour
# 10    1.021390          Dep_Min
# 11    1.036506     Arrival_Hour
# 12    1.096141      Arrival_Min

# %% [markdown]
# **Independent feature VIF is within permissible limit of 10**

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %% [markdown]
# #### Comment -
# <b> AS per the graph, we can see that 9 principal components attribute for 90% of variation in the data.  We shall pick the first 9 components for our prediction. </b>

# %%
pca_new = PCA(n_components=9)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(9))

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from xgboost import XGBRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (6893, 13)
# Training target vector size: (6893,)
# Test feature matrix size: (3396, 13)
# Test target vector size: (3396,)

# %% [markdown]
# ### Finding best Random state

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,500):
    X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.5159382902827081 on Random_state 214

# %% [markdown]
# ## Linear Regression Base Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=214, test_size=.33)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted Wins:'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual Wins:'+'\033[0m\n',Y_test)
# Out:
# Predicted Wins:
#  [ 4488.64736916 10989.97240682 12492.30578063 ...  7971.32189149
#   5310.4903453   6269.23098453]
#
#
# Actual Wins:
#  5766     4804
# 4006     6416
# 9528    19329
# 5509    13029
# 2138    16163
#         ...
# 1391     6582
# 5473     6979
# 7999     6152
# 1909     8016
# 75       7240
# Name: Price, Length: 3396, dtype: int64

# %% [markdown]
# ### Linear Regression Evaluation Matrix

# %%
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))
# Out:
#  Error :
# Mean absolute error : 2237.4521917417046
# Mean squared error : 7986749.490730628
# Root Mean Squared Error: 2826.0837727729568
#
#
#  R2 Score :
# 0.5159382902827081

# %% [markdown]
# #### Cross validation

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, X_scale, Y, cv =3)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : 0.488961585067113

# %% [markdown]
# ### Applying other ML Models

# %%
from sklearn.ensemble import BaggingRegressor

# %%
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
XT = ExtraTreesRegressor()
BR = BaggingRegressor()
adb=AdaBoostRegressor()
gradb=GradientBoostingRegressor()
xgb=XGBRegressor()
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    print('==============================================================================================================')
# Out:
#  Error of  RandomForestRegressor() :
# Mean absolute error : 613.4537618977508
# Mean squared error : 1280686.320230479
# Root Mean Squared Error: 1131.6741228067729
#
#
#  R2 Score :
# 0.9223800357702716
# ==============================================================================================================
#
#
#  Error of  ExtraTreesRegressor() :
# Mean absolute error : 607.8341131723596
# Mean squared error : 1306332.4248805384
# Root Mean Squared Error: 1142.949003622007
#
#
#  R2 Score :
# 0.9208256741017474
# ==============================================================================================================
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 697.0090302316452
# Mean squared error : 2182295.860227719
# Root Mean Squared Error: 1477.2595778087612
#
#
#  R2 Score :
# 0.867735194845311
# ==============================================================================================================
#
#
#  Error of  AdaBoostRegressor() :
# Mean absolute error : 2015.7185369109536
# Mean squared error : 5996042.932359945
# Root Mean Squared Error: 2448.68187651233
#
#
#  R2 Score :
# 0.636591231921696
# ==============================================================================================================
#
#
#  Error of  GradientBoostingRegressor() :
# Mean absolute error : 1115.0802015698166
# Mean squared error : 2388644.909831967
# Root Mean Squared Error: 1545.5241537523661
#
#
#  R2 Score :
# 0.855228771066038
# ==============================================================================================================
#
#
#  Error of  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None) :
# Mean absolute error : 672.3322522777831
# Mean squared error : 1111184.1223003382
# Root Mean Squared Error: 1054.1271850684518
#
#
#  R2 Score :
# 0.932653241888246
# ==============================================================================================================

# %%
# Cross Validation
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.9211028303877168
# ==============================================================================================================
#
#
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : 0.9210275687658024
# ==============================================================================================================
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.8726845675589674
# ==============================================================================================================
#
#
# Cross Validation Score : AdaBoostRegressor() :
#
# Mean CV Score : 0.6025393473448822
# ==============================================================================================================
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.8414184025829046
# ==============================================================================================================
#
#
# Cross Validation Score : XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None) :
#
# Mean CV Score : 0.9305614588699157
# ==============================================================================================================

# %% [markdown]
# **XGB regressor gives maximum R2 Score of 0.9326 with crossvalidation score 0.93056. So we will perform hyperparameter tuning on this model.**

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'n_estimators':[50,75,100],'gamma':np.arange(0,0.2,0.1),
              'booster' : ['gbtree','dart','gblinear'], 'max_depth':[4,6,8,10],
              'eta' : [0.001, 0.01, 0.1] }

# %%
GCV = GridSearchCV(XGBRegressor(),parameter,verbose =10)

# %%
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV 1/5; 1/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50
# [CV 1/5; 1/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50;, score=-4.312 total time=   0.2s
# [CV 2/5; 1/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50
# [CV 2/5; 1/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50;, score=-4.114 total time=   0.3s
# [CV 3/5; 1/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50
# [CV 3/5; 1/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50;, score=-4.277 total time=   0.3s
# [CV 4/5; 1/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50
# [CV 4/5; 1/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50;, score=-4.178 total time=   0.3s
# [CV 5/5; 1/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50
# [CV 5/5; 1/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50;, score=-4.287 total time=   0.4s
# [CV 1/5; 2/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75
# [CV 1/5; 2/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75;, score=-4.068 total time=   0.5s
# [CV 2/5; 2/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75
# [CV 2/5; 2/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75;, score=-3.879 total time=   0.7s
# [CV 3/5; 2/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75
# [CV 3/5; 2/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75;, score=-4.032 total time=   0.4s
# [CV 4/5; 2/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75
# [CV 4/5; 2/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75;, score=-3.942 total time=   0.3s
# [CV 5/5; 2/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75
# [CV 5/5; 2/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=75;, score=-4.048 total time=   0.4s
# [CV 1/5; 3/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100
# [CV 1/5; 3/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100;, score=-3.836 total time=   0.5s
# [CV 2/5; 3/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100
# [CV 2/5; 3/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100;, score=-3.656 total time=   0.5s
# [CV 3/5; 3/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100
# [CV 3/5; 3/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100;, score=-3.799 total time=   0.6s
# [CV 4/5; 3/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100
# [CV 4/5; 3/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100;, score=-3.717 total time=   0.6s
# [CV 5/5; 3/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100
# [CV 5/5; 3/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=100;, score=-3.821 total time=   0.5s
# [CV 1/5; 4/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50
# [CV 1/5; 4/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50;, score=-4.308 total time=   0.4s
# [CV 2/5; 4/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50
# [CV 2/5; 4/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50;, score=-4.106 total time=   0.4s
# [CV 3/5; 4/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50
# [CV 3/5; 4/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50;, score=-4.268 total time=   0.4s
# [CV 4/5; 4/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50
# [CV 4/5; 4/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50;, score=-4.172 total time=   0.4s
# [CV 5/5; 4/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50
# [CV 5/5; 4/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=50;, score=-4.279 total time=   0.6s
# [CV 1/5; 5/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75
# [CV 1/5; 5/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75;, score=-4.062 total time=   1.2s
# [CV 2/5; 5/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75
# [CV 2/5; 5/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75;, score=-3.868 total time=   0.9s
# [CV 3/5; 5/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75
# [CV 3/5; 5/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75;, score=-4.019 total time=   0.9s
# [CV 4/5; 5/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75
# [CV 4/5; 5/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75;, score=-3.931 total time=   0.8s
# [CV 5/5; 5/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75
# [CV 5/5; 5/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=75;, score=-4.036 total time=   0.7s
# [CV 1/5; 6/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100
# [CV 1/5; 6/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100;, score=-3.828 total time=   0.9s
# [CV 2/5; 6/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100
# [CV 2/5; 6/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100;, score=-3.641 total time=   1.1s
# [CV 3/5; 6/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100
# [CV 3/5; 6/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100;, score=-3.782 total time=   1.2s
# [CV 4/5; 6/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100
# [CV 4/5; 6/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100;, score=-3.702 total time=   1.3s
# [CV 5/5; 6/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100
# [CV 5/5; 6/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=6, n_estimators=100;, score=-3.805 total time=   1.2s
# [CV 1/5; 7/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50
# [CV 1/5; 7/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50;, score=-4.307 total time=   0.6s
# [CV 2/5; 7/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50
# [CV 2/5; 7/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50;, score=-4.106 total time=   0.7s
# [CV 3/5; 7/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50
# [CV 3/5; 7/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50;, score=-4.267 total time=   0.7s
# [CV 4/5; 7/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50
# [CV 4/5; 7/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50;, score=-4.169 total time=   0.8s
# [CV 5/5; 7/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50
# [CV 5/5; 7/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=50;, score=-4.277 total time=   0.7s
# [CV 1/5; 8/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75
# [CV 1/5; 8/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75;, score=-4.060 total time=   1.2s
# [CV 2/5; 8/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75
# [CV 2/5; 8/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75;, score=-3.868 total time=   1.0s
# [CV 3/5; 8/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75
# [CV 3/5; 8/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75;, score=-4.017 total time=   1.0s
# [CV 4/5; 8/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75
# [CV 4/5; 8/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75;, score=-3.928 total time=   0.9s
# [CV 5/5; 8/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75
# [CV 5/5; 8/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=75;, score=-4.033 total time=   0.8s
# [CV 1/5; 9/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100
# [CV 1/5; 9/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100;, score=-3.826 total time=   1.2s
# [CV 2/5; 9/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100
# [CV 2/5; 9/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100;, score=-3.641 total time=   2.2s
# [CV 3/5; 9/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100
# [CV 3/5; 9/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100;, score=-3.780 total time=   1.8s
# [CV 4/5; 9/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100
# [CV 4/5; 9/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100;, score=-3.698 total time=   1.5s
# [CV 5/5; 9/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100
# [CV 5/5; 9/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=8, n_estimators=100;, score=-3.801 total time=   1.6s
# [CV 1/5; 10/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50
# [CV 1/5; 10/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50;, score=-4.307 total time=   0.9s
# [CV 2/5; 10/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50
# [CV 2/5; 10/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50;, score=-4.105 total time=   0.9s
# [CV 3/5; 10/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50
# [CV 3/5; 10/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50;, score=-4.266 total time=   1.1s
# [CV 4/5; 10/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50
# [CV 4/5; 10/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50;, score=-4.169 total time=   1.0s
# [CV 5/5; 10/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50
# [CV 5/5; 10/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=50;, score=-4.277 total time=   1.0s
# [CV 1/5; 11/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75
# [CV 1/5; 11/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75;, score=-4.060 total time=   1.2s
# [CV 2/5; 11/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75
# [CV 2/5; 11/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75;, score=-3.867 total time=   1.1s
# [CV 3/5; 11/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75
# [CV 3/5; 11/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75;, score=-4.016 total time=   1.5s
# [CV 4/5; 11/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75
# [CV 4/5; 11/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75;, score=-3.928 total time=   1.8s
# [CV 5/5; 11/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75
# [CV 5/5; 11/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=75;, score=-4.033 total time=   1.3s
# [CV 1/5; 12/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100
# [CV 1/5; 12/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100;, score=-3.825 total time=   1.5s
# [CV 2/5; 12/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100
# [CV 2/5; 12/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100;, score=-3.640 total time=   1.7s
# [CV 3/5; 12/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100
# [CV 3/5; 12/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100;, score=-3.778 total time=   1.5s
# [CV 4/5; 12/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100
# [CV 4/5; 12/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100;, score=-3.699 total time=   1.5s
# [CV 5/5; 12/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100
# [CV 5/5; 12/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=10, n_estimators=100;, score=-3.801 total time=   1.8s
# [CV 1/5; 13/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50
# [CV 1/5; 13/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50;, score=-4.312 total time=   0.3s
# [CV 2/5; 13/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50
# [CV 2/5; 13/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50;, score=-4.114 total time=   0.2s
# [CV 3/5; 13/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50
# [CV 3/5; 13/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50;, score=-4.277 total time=   0.2s
# [CV 4/5; 13/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50
# [CV 4/5; 13/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50;, score=-4.178 total time=   0.2s
# [CV 5/5; 13/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50
# [CV 5/5; 13/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=50;, score=-4.287 total time=   0.2s
# [CV 1/5; 14/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75
# [CV 1/5; 14/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75;, score=-4.068 total time=   0.5s
# [CV 2/5; 14/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75
# [CV 2/5; 14/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75;, score=-3.879 total time=   0.4s
# [CV 3/5; 14/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75
# [CV 3/5; 14/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75;, score=-4.032 total time=   0.7s
# [CV 4/5; 14/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75
# [CV 4/5; 14/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75;, score=-3.942 total time=   1.0s
# [CV 5/5; 14/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75
# [CV 5/5; 14/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=75;, score=-4.048 total time=   0.9s
# [CV 1/5; 15/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100
# [CV 1/5; 15/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100;, score=-3.836 total time=   0.8s
# [CV 2/5; 15/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100
# [CV 2/5; 15/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100;, score=-3.656 total time=   0.5s
# [CV 3/5; 15/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100
# [CV 3/5; 15/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100;, score=-3.799 total time=   0.5s
# [CV 4/5; 15/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100
# [CV 4/5; 15/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100;, score=-3.717 total time=   0.5s
# [CV 5/5; 15/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100
# [CV 5/5; 15/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=4, n_estimators=100;, score=-3.821 total time=   0.5s
# [CV 1/5; 16/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50
# [CV 1/5; 16/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50;, score=-4.308 total time=   0.4s
# [CV 2/5; 16/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50
# [CV 2/5; 16/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50;, score=-4.106 total time=   0.7s
# [CV 3/5; 16/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50
# [CV 3/5; 16/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50;, score=-4.268 total time=   0.4s
# [CV 4/5; 16/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50
# [CV 4/5; 16/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50;, score=-4.172 total time=   0.5s
# [CV 5/5; 16/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50
# [CV 5/5; 16/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=50;, score=-4.279 total time=   0.4s
# [CV 1/5; 17/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75
# [CV 1/5; 17/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75;, score=-4.062 total time=   0.7s
# [CV 2/5; 17/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75
# [CV 2/5; 17/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75;, score=-3.868 total time=   0.6s
# [CV 3/5; 17/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75
# [CV 3/5; 17/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75;, score=-4.019 total time=   0.6s
# [CV 4/5; 17/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75
# [CV 4/5; 17/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75;, score=-3.931 total time=   0.9s
# [CV 5/5; 17/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75
# [CV 5/5; 17/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=75;, score=-4.036 total time=   0.8s
# [CV 1/5; 18/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100
# [CV 1/5; 18/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100;, score=-3.828 total time=   1.3s
# [CV 2/5; 18/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100
# [CV 2/5; 18/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100;, score=-3.641 total time=   0.9s
# [CV 3/5; 18/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100
# [CV 3/5; 18/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100;, score=-3.782 total time=   1.3s
# [CV 4/5; 18/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100
# [CV 4/5; 18/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100;, score=-3.702 total time=   1.5s
# [CV 5/5; 18/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100
# [CV 5/5; 18/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=6, n_estimators=100;, score=-3.805 total time=   1.1s
# [CV 1/5; 19/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50
# [CV 1/5; 19/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50;, score=-4.307 total time=   0.6s
# [CV 2/5; 19/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50
# [CV 2/5; 19/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50;, score=-4.106 total time=   0.7s
# [CV 3/5; 19/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50
# [CV 3/5; 19/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50;, score=-4.267 total time=   0.8s
# [CV 4/5; 19/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50
# [CV 4/5; 19/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50;, score=-4.169 total time=   0.8s
# [CV 5/5; 19/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50
# [CV 5/5; 19/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=50;, score=-4.277 total time=   0.8s
# [CV 1/5; 20/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75
# [CV 1/5; 20/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75;, score=-4.060 total time=   0.9s
# [CV 2/5; 20/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75
# [CV 2/5; 20/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75;, score=-3.868 total time=   0.8s
# [CV 3/5; 20/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75
# [CV 3/5; 20/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75;, score=-4.017 total time=   1.0s
# [CV 4/5; 20/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75
# [CV 4/5; 20/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75;, score=-3.928 total time=   1.0s
# [CV 5/5; 20/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75
# [CV 5/5; 20/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=75;, score=-4.033 total time=   1.0s
# [CV 1/5; 21/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100
# [CV 1/5; 21/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100;, score=-3.826 total time=   1.2s
# [CV 2/5; 21/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100
# [CV 2/5; 21/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100;, score=-3.641 total time=   1.7s
# [CV 3/5; 21/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100
# [CV 3/5; 21/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100;, score=-3.780 total time=   1.8s
# [CV 4/5; 21/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100
# [CV 4/5; 21/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100;, score=-3.698 total time=   1.5s
# [CV 5/5; 21/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100
# [CV 5/5; 21/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=8, n_estimators=100;, score=-3.801 total time=   1.7s
# [CV 1/5; 22/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50
# [CV 1/5; 22/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50;, score=-4.307 total time=   0.8s
# [CV 2/5; 22/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50
# [CV 2/5; 22/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50;, score=-4.105 total time=   0.9s
# [CV 3/5; 22/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50
# [CV 3/5; 22/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50;, score=-4.266 total time=   0.8s
# [CV 4/5; 22/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50
# [CV 4/5; 22/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50;, score=-4.169 total time=   1.0s
# [CV 5/5; 22/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50
# [CV 5/5; 22/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=50;, score=-4.277 total time=   0.7s
# [CV 1/5; 23/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75
# [CV 1/5; 23/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75;, score=-4.060 total time=   1.0s
# [CV 2/5; 23/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75
# [CV 2/5; 23/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75;, score=-3.867 total time=   1.0s
# [CV 3/5; 23/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75
# [CV 3/5; 23/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75;, score=-4.016 total time=   1.0s
# [CV 4/5; 23/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75
# [CV 4/5; 23/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75;, score=-3.928 total time=   1.2s
# [CV 5/5; 23/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75
# [CV 5/5; 23/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=75;, score=-4.033 total time=   1.5s
# [CV 1/5; 24/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100
# [CV 1/5; 24/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100;, score=-3.825 total time=   2.4s
# [CV 2/5; 24/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100
# [CV 2/5; 24/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100;, score=-3.640 total time=   1.6s
# [CV 3/5; 24/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100
# [CV 3/5; 24/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100;, score=-3.778 total time=   1.7s
# [CV 4/5; 24/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100
# [CV 4/5; 24/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100;, score=-3.699 total time=   1.9s
# [CV 5/5; 24/216] START booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100
# [CV 5/5; 24/216] END booster=gbtree, eta=0.001, gamma=0.1, max_depth=10, n_estimators=100;, score=-3.801 total time=   1.7s
# [CV 1/5; 25/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50
# [CV 1/5; 25/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50;, score=-1.333 total time=   0.2s
# [CV 2/5; 25/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50
# [CV 2/5; 25/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50;, score=-1.245 total time=   0.4s
# [CV 3/5; 25/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50
# [CV 3/5; 25/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50;, score=-1.279 total time=   0.3s
# [CV 4/5; 25/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50
# [CV 4/5; 25/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50;, score=-1.289 total time=   0.3s
# [CV 5/5; 25/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50
# [CV 5/5; 25/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=50;, score=-1.357 total time=   0.3s
# [CV 1/5; 26/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75
# [CV 1/5; 26/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75;, score=-0.526 total time=   0.5s
# [CV 2/5; 26/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75
# [CV 2/5; 26/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75;, score=-0.468 total time=   0.4s
# [CV 3/5; 26/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75
# [CV 3/5; 26/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75;, score=-0.471 total time=   0.5s
# [CV 4/5; 26/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75
# [CV 4/5; 26/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75;, score=-0.499 total time=   0.5s
# [CV 5/5; 26/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75
# [CV 5/5; 26/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=75;, score=-0.557 total time=   0.5s
# [CV 1/5; 27/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100
# [CV 1/5; 27/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100;, score=-0.029 total time=   0.6s
# [CV 2/5; 27/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100
# [CV 2/5; 27/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100;, score=0.010 total time=   0.8s
# [CV 3/5; 27/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100
# [CV 3/5; 27/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100;, score=0.022 total time=   1.3s
# [CV 4/5; 27/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100
# [CV 4/5; 27/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100;, score=-0.016 total time=   1.1s
# [CV 5/5; 27/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100
# [CV 5/5; 27/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=4, n_estimators=100;, score=-0.061 total time=   0.9s
# [CV 1/5; 28/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50
# [CV 1/5; 28/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50;, score=-1.299 total time=   0.5s
# [CV 2/5; 28/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50
# [CV 2/5; 28/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50;, score=-1.196 total time=   0.4s
# [CV 3/5; 28/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50
# [CV 3/5; 28/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50;, score=-1.226 total time=   0.4s
# [CV 4/5; 28/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50
# [CV 4/5; 28/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50;, score=-1.231 total time=   0.5s
# [CV 5/5; 28/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50
# [CV 5/5; 28/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=50;, score=-1.292 total time=   0.4s
# [CV 1/5; 29/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75
# [CV 1/5; 29/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75;, score=-0.479 total time=   0.7s
# [CV 2/5; 29/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75
# [CV 2/5; 29/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75;, score=-0.409 total time=   0.7s
# [CV 3/5; 29/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75
# [CV 3/5; 29/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75;, score=-0.405 total time=   0.8s
# [CV 4/5; 29/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75
# [CV 4/5; 29/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75;, score=-0.434 total time=   0.8s
# [CV 5/5; 29/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75
# [CV 5/5; 29/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=75;, score=-0.476 total time=   0.9s
# [CV 1/5; 30/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100
# [CV 1/5; 30/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100;, score=0.025 total time=   1.0s
# [CV 2/5; 30/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100
# [CV 2/5; 30/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100;, score=0.072 total time=   0.9s
# [CV 3/5; 30/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100
# [CV 3/5; 30/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100;, score=0.094 total time=   1.0s
# [CV 4/5; 30/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100
# [CV 4/5; 30/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100;, score=0.054 total time=   0.9s
# [CV 5/5; 30/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100
# [CV 5/5; 30/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=100;, score=0.027 total time=   1.2s
# [CV 1/5; 31/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50
# [CV 1/5; 31/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50;, score=-1.280 total time=   0.8s
# [CV 2/5; 31/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50
# [CV 2/5; 31/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50;, score=-1.187 total time=   0.8s
# [CV 3/5; 31/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50
# [CV 3/5; 31/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50;, score=-1.211 total time=   0.6s
# [CV 4/5; 31/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50
# [CV 4/5; 31/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50;, score=-1.220 total time=   0.7s
# [CV 5/5; 31/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50
# [CV 5/5; 31/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=50;, score=-1.275 total time=   0.6s
# [CV 1/5; 32/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75
# [CV 1/5; 32/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75;, score=-0.456 total time=   1.0s
# [CV 2/5; 32/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75
# [CV 2/5; 32/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75;, score=-0.397 total time=   1.0s
# [CV 3/5; 32/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75
# [CV 3/5; 32/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75;, score=-0.383 total time=   1.1s
# [CV 4/5; 32/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75
# [CV 4/5; 32/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75;, score=-0.418 total time=   1.0s
# [CV 5/5; 32/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75
# [CV 5/5; 32/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=75;, score=-0.454 total time=   1.0s
# [CV 1/5; 33/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100
# [CV 1/5; 33/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100;, score=0.052 total time=   1.3s
# [CV 2/5; 33/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100
# [CV 2/5; 33/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100;, score=0.089 total time=   1.3s
# [CV 3/5; 33/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100
# [CV 3/5; 33/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100;, score=0.122 total time=   1.3s
# [CV 4/5; 33/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100
# [CV 4/5; 33/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100;, score=0.075 total time=   1.5s
# [CV 5/5; 33/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100
# [CV 5/5; 33/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=100;, score=0.054 total time=   2.8s
# [CV 1/5; 34/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50
# [CV 1/5; 34/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50;, score=-1.276 total time=   0.8s
# [CV 2/5; 34/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50
# [CV 2/5; 34/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50;, score=-1.179 total time=   1.1s
# [CV 3/5; 34/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50
# [CV 3/5; 34/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50;, score=-1.205 total time=   1.0s
# [CV 4/5; 34/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50
# [CV 4/5; 34/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50;, score=-1.219 total time=   1.0s
# [CV 5/5; 34/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50
# [CV 5/5; 34/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=50;, score=-1.275 total time=   1.1s
# [CV 1/5; 35/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75
# [CV 1/5; 35/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75;, score=-0.447 total time=   1.2s
# [CV 2/5; 35/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75
# [CV 2/5; 35/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75;, score=-0.387 total time=   1.5s
# [CV 3/5; 35/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75
# [CV 3/5; 35/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75;, score=-0.375 total time=   1.5s
# [CV 4/5; 35/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75
# [CV 4/5; 35/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75;, score=-0.416 total time=   1.4s
# [CV 5/5; 35/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75
# [CV 5/5; 35/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=75;, score=-0.452 total time=   1.2s
# [CV 1/5; 36/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100
# [CV 1/5; 36/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100;, score=0.063 total time=   2.0s
# [CV 2/5; 36/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100
# [CV 2/5; 36/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100;, score=0.100 total time=   1.6s
# [CV 3/5; 36/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100
# [CV 3/5; 36/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100;, score=0.132 total time=   1.8s
# [CV 4/5; 36/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100
# [CV 4/5; 36/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100;, score=0.078 total time=   1.7s
# [CV 5/5; 36/216] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100
# [CV 5/5; 36/216] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=10, n_estimators=100;, score=0.058 total time=   1.5s
# [CV 1/5; 37/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50
# [CV 1/5; 37/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50;, score=-1.333 total time=   0.2s
# [CV 2/5; 37/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50
# [CV 2/5; 37/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50;, score=-1.245 total time=   0.3s
# [CV 3/5; 37/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50
# [CV 3/5; 37/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50;, score=-1.279 total time=   0.5s
# [CV 4/5; 37/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50
# [CV 4/5; 37/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50;, score=-1.289 total time=   0.2s
# [CV 5/5; 37/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50
# [CV 5/5; 37/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=50;, score=-1.357 total time=   0.2s
# [CV 1/5; 38/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75
# [CV 1/5; 38/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75;, score=-0.526 total time=   0.4s
# [CV 2/5; 38/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75
# [CV 2/5; 38/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75;, score=-0.468 total time=   0.3s
# [CV 3/5; 38/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75
# [CV 3/5; 38/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75;, score=-0.471 total time=   0.3s
# [CV 4/5; 38/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75
# [CV 4/5; 38/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75;, score=-0.499 total time=   0.3s
# [CV 5/5; 38/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75
# [CV 5/5; 38/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=75;, score=-0.557 total time=   0.3s
# [CV 1/5; 39/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100
# [CV 1/5; 39/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100;, score=-0.029 total time=   0.5s
# [CV 2/5; 39/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100
# [CV 2/5; 39/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100;, score=0.010 total time=   0.6s
# [CV 3/5; 39/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100
# [CV 3/5; 39/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100;, score=0.022 total time=   0.8s
# [CV 4/5; 39/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100
# [CV 4/5; 39/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100;, score=-0.016 total time=   0.6s
# [CV 5/5; 39/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100
# [CV 5/5; 39/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=4, n_estimators=100;, score=-0.061 total time=   0.6s
# [CV 1/5; 40/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50
# [CV 1/5; 40/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50;, score=-1.299 total time=   0.5s
# [CV 2/5; 40/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50
# [CV 2/5; 40/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50;, score=-1.196 total time=   0.5s
# [CV 3/5; 40/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50
# [CV 3/5; 40/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50;, score=-1.226 total time=   0.4s
# [CV 4/5; 40/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50
# [CV 4/5; 40/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50;, score=-1.231 total time=   0.4s
# [CV 5/5; 40/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50
# [CV 5/5; 40/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=50;, score=-1.292 total time=   0.4s
# [CV 1/5; 41/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75
# [CV 1/5; 41/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75;, score=-0.479 total time=   0.7s
# [CV 2/5; 41/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75
# [CV 2/5; 41/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75;, score=-0.409 total time=   0.8s
# [CV 3/5; 41/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75
# [CV 3/5; 41/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75;, score=-0.405 total time=   0.6s
# [CV 4/5; 41/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75
# [CV 4/5; 41/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75;, score=-0.434 total time=   0.6s
# [CV 5/5; 41/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75
# [CV 5/5; 41/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=75;, score=-0.476 total time=   0.6s
# [CV 1/5; 42/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100
# [CV 1/5; 42/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100;, score=0.025 total time=   1.0s
# [CV 2/5; 42/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100
# [CV 2/5; 42/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100;, score=0.072 total time=   0.9s
# [CV 3/5; 42/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100
# [CV 3/5; 42/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100;, score=0.094 total time=   1.0s
# [CV 4/5; 42/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100
# [CV 4/5; 42/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100;, score=0.054 total time=   0.8s
# [CV 5/5; 42/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100
# [CV 5/5; 42/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=100;, score=0.027 total time=   0.9s
# [CV 1/5; 43/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50
# [CV 1/5; 43/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50;, score=-1.280 total time=   0.7s
# [CV 2/5; 43/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50
# [CV 2/5; 43/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50;, score=-1.187 total time=   0.7s
# [CV 3/5; 43/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50
# [CV 3/5; 43/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50;, score=-1.211 total time=   0.7s
# [CV 4/5; 43/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50
# [CV 4/5; 43/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50;, score=-1.220 total time=   0.6s
# [CV 5/5; 43/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50
# [CV 5/5; 43/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=50;, score=-1.275 total time=   0.5s
# [CV 1/5; 44/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75
# [CV 1/5; 44/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75;, score=-0.456 total time=   1.5s
# [CV 2/5; 44/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75
# [CV 2/5; 44/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75;, score=-0.397 total time=   1.3s
# [CV 3/5; 44/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75
# [CV 3/5; 44/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75;, score=-0.383 total time=   1.0s
# [CV 4/5; 44/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75
# [CV 4/5; 44/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75;, score=-0.418 total time=   0.9s
# [CV 5/5; 44/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75
# [CV 5/5; 44/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=75;, score=-0.454 total time=   1.0s
# [CV 1/5; 45/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100
# [CV 1/5; 45/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100;, score=0.052 total time=   1.7s
# [CV 2/5; 45/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100
# [CV 2/5; 45/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100;, score=0.089 total time=   1.7s
# [CV 3/5; 45/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100
# [CV 3/5; 45/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100;, score=0.122 total time=   1.4s
# [CV 4/5; 45/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100
# [CV 4/5; 45/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100;, score=0.075 total time=   1.3s
# [CV 5/5; 45/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100
# [CV 5/5; 45/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=100;, score=0.054 total time=   1.5s
# [CV 1/5; 46/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=10, n_estimators=50
# [CV 1/5; 46/216] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=10, n_estimators=50;, score=-1.276 total time=   0.8s
# [CV 2/5; 46/216] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=10, n_estimators=50
# ...
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 212/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=75;, score=0.493 total time=   0.1s
# [CV 4/5; 212/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=75
# [18:33:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 212/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=75;, score=0.474 total time=   0.1s
# [CV 5/5; 212/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=75
# [18:33:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 212/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=75;, score=0.441 total time=   0.1s
# [CV 1/5; 213/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100
# [18:33:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 213/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100;, score=0.483 total time=   0.1s
# [CV 2/5; 213/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100
# [18:33:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 213/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100;, score=0.488 total time=   0.1s
# [CV 3/5; 213/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100
# [18:33:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 213/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100;, score=0.493 total time=   0.1s
# [CV 4/5; 213/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100
# [18:33:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 213/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100;, score=0.474 total time=   0.2s
# [CV 5/5; 213/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100
# [18:33:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 213/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=100;, score=0.441 total time=   0.1s
# [CV 1/5; 214/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50
# [18:33:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 214/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50;, score=0.482 total time=   0.0s
# [CV 2/5; 214/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50
# [18:33:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 214/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50;, score=0.486 total time=   0.0s
# [CV 3/5; 214/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50
# [18:33:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 214/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50;, score=0.493 total time=   0.1s
# [CV 4/5; 214/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50
# [18:33:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 214/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50;, score=0.473 total time=   0.1s
# [CV 5/5; 214/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50
# [18:33:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 214/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=50;, score=0.438 total time=   0.2s
# [CV 1/5; 215/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75
# [18:33:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 215/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75;, score=0.483 total time=   0.1s
# [CV 2/5; 215/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75
# [18:33:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 2/5; 215/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75;, score=0.487 total time=   0.1s
# [CV 3/5; 215/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75
# [18:33:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 215/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75;, score=0.493 total time=   0.3s
# [CV 4/5; 215/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75
# [18:33:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 215/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75;, score=0.474 total time=   0.1s
# [CV 5/5; 215/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75
# [18:33:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 215/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=75;, score=0.441 total time=   0.3s
# [CV 1/5; 216/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100
# [18:33:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 216/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100;, score=0.483 total time=   0.1s
# [CV 2/5; 216/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100
# [18:33:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 216/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100;, score=0.488 total time=   0.3s
# [CV 3/5; 216/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100
# [18:33:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 216/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100;, score=0.493 total time=   0.1s
# [CV 4/5; 216/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100
# [18:33:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 216/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100;, score=0.474 total time=   0.1s
# [CV 5/5; 216/216] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100
# [18:33:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 216/216] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=10, n_estimators=100;, score=0.441 total time=   0.2s
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     enable_categorical=False, gamma=None,
#                                     gpu_id=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_esti...bs=None,
#                                     num_parallel_tree=None, predictor=None,
#                                     random_state=None, reg_alpha=None,
#                                     reg_lambda=None, scale_pos_weight=None,
#                                     subsample=None, tree_method=None,
#                                     validate_parameters=None, verbosity=None),
#              param_grid={'booster': ['gbtree', 'dart', 'gblinear'],
#                          'eta': [0.001, 0.01, 0.1], 'gamma': array([0. , 0.1]),
#                          'max_depth': [4, 6, 8, 10],
#                          'n_estimators': [50, 75, 100]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'booster': 'dart',
#  'eta': 0.1,
#  'gamma': 0.0,
#  'max_depth': 8,
#  'n_estimators': 100}

# %% [markdown]
# ## Final Regression Model

# %%
Final_mod =  XGBRegressor(n_estimators=100 , booster= 'dart', eta= 0.1, max_depth= 8, gamma= 0.0 )
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')
# Out:
#  Error in Final Model :
# Mean absolute error : 650.3808400364169
# Mean squared error : 1113372.0682012036
# Root Mean Squared Error: 1055.1644744783648
#
#
#  R2 Score of Final Model :
# 0.9325206346448648

# %%
plt.figure(figsize=(12,7))
y_pred=Final_mod.predict(X_test)
sns.swarmplot(Y_test.round(2), y_pred)
print('\033[1m'+' True Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()
# Out:
#  True Values Vs Predicted Value plot :

# %% [markdown]
# ## Final Regression For Train Dataset Saving Model

# %%
import joblib
joblib.dump(Final_mod,'Flight_Price_Final.pkl')
# Out:
# ['Flight_Price_Final.pkl']

# %% [markdown]
# ### Prediction According Final Regression Model

# %%
# Loading the saved model
Model = joblib.load("Flight_Price_Final.pkl")

# prediction  DataFrame
actual = np.array(Y_test)
predicted = np.array(Model.predict(X_test))
df_Predicted = pd.DataFrame({"Actual Values":actual,"Predicted Values":predicted},index= range(len(actual)))
df_Predicted
# Out:
#       Actual Values  Predicted Values
# 0              4804       4802.051758
# 1              6416       6762.949219
# 2             19329      17346.197266
# 3             13029      12854.145508
# 4             16163      14054.752930
# ...             ...               ...
# 3391           6582       6042.802734
# 3392           6979       6981.562012
# 3393           6152       6750.864746
# 3394           8016       7852.672363
# 3395           7240       7951.234375
#
# [3396 rows x 2 columns]

# %% [markdown]
# # ML Model for Test Dataset

# %%
test_df = pd.read_excel("Test_set.xlsx")

# %%
test_df.shape
# Out:
# (2671, 10)

# %% [markdown]
# ## Feature Engineering Test Dataset

# %% [markdown]
# **We will perform same feature which we perform on Train dataset.**

# %% [markdown]
#  **Converting Date and time columns from object type to Datetime type**

# %%
# Converting Date and Time columns from object type to Date type
test_df['Date_of_Journey']=pd.to_datetime(test_df['Date_of_Journey'])
test_df['Dep_Time']=pd.to_datetime(test_df['Dep_Time'])
test_df['Arrival_Time']=pd.to_datetime(test_df['Arrival_Time'])

# %% [markdown]
# **1. Feature Engineering on Date of Journey Columns**

# %%
# Extracting Day from Date_of_journey column
test_df['Journey_Day'] = pd.to_datetime(test_df.Date_of_Journey,format="%d/%m/%Y").dt.day

# Extracting Month from Date_of_journey column
test_df['Journey_Month'] = pd.to_datetime(test_df.Date_of_Journey, format="%d/%m/%Y").dt.month

# Dropping Date_of_journey column
test_df.drop("Date_of_Journey",axis=1,inplace=True)

# %% [markdown]
# **2. Feature Engineering on 'Duration' Column**

# %%
test_df['Duration']=test_df['Duration'].str.replace('h','*60').str.replace(' ','+').str.replace('m','*1').apply(eval)
# convert this column into a numeric
test_df['Duration']=pd.to_numeric(test_df['Duration'])

# %% [markdown]
# **3. Feature Engineering on 'Dep_Time' Column**

# %%
# Extracting Hours from Dep_Time column
test_df['Dep_Hour']=pd.to_datetime(test_df['Dep_Time']).dt.hour

# Extracting Minutes from Dep_Time column
test_df['Dep_Min']=pd.to_datetime(test_df['Dep_Time']).dt.minute

# Dropping Dep_Time column
test_df.drop("Dep_Time",axis=1,inplace=True)

# %% [markdown]
# **4. Feature Engineering on 'Arrival_Time' Column**

# %%
# Extracting Arrival_Hour from Arrival_Time column
test_df['Arrival_Hour']=pd.to_datetime(test_df['Arrival_Time']).dt.hour

# Extracting Arrival_Min from Arrival_Time column
test_df['Arrival_Min']=pd.to_datetime(test_df['Arrival_Time']).dt.minute

# Dropping Arruval_Time column
test_df.drop("Arrival_Time",axis=1,inplace=True)

# %%
# Replacing "New Delhi" as "Delhi" in Destination column
test_df["Destination"] = test_df["Destination"].replace("New Delhi","Delhi")

# In the column Additional Info, "No Info" and "No info" are one and the same so replace it by "No Info" 
test_df["Additional_Info"] = test_df["Additional_Info"].replace("No info","No Info")

# %% [markdown]
# **Checking Duplicate entry**

# %%
test_df.duplicated().sum() # This will check the duplicate data for all columns.
# Out:
# 26

# %%
test_df.drop_duplicates(keep='last',inplace= True)

# %%
test_df.shape
# Out:
# (2645, 13)

# %% [markdown]
# **Checking Missing Value**

# %%
#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                  Missing Values  % Missing data
# Arrival_Min                   0             0.0
# Arrival_Hour                  0             0.0
# Dep_Min                       0             0.0
# Dep_Hour                      0             0.0
# Journey_Month                 0             0.0
# Journey_Day                   0             0.0
# Price                         0             0.0
# Additional_Info               0             0.0
# Total_Stops                   0             0.0
# Duration                      0             0.0
# Route                         0             0.0
# Destination                   0             0.0
# Source                        0             0.0
# Airline                       0             0.0

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Categorical:
    test_df[i] = le.fit_transform(test_df[i])
test_df.head()
# Out:
#    Airline  Source  Destination  Route  Duration  Total_Stops  \
# 0        4       2            1     76       655            0
# 1        3       3            0     65       240            0
# 2        4       2            1     76      1425            0
# 3        6       2            1     76       780            0
# 4        0       0            2     16       170            4
#
#    Additional_Info  Journey_Day  Journey_Month  Dep_Hour  Dep_Min  \
# 0                4            6              6        17       30
# 1                4            5             12         6       20
# 2                3           21              5        19       15
# 3                4           21              5         8        0
# 4                4           24              6        23       55
#
#    Arrival_Hour  Arrival_Min
# 0             4           25
# 1            10           20
# 2            19            0
# 3            21            0
# 4             2           45

# %% [markdown]
# ### Outliers detection and removal

# %%
from scipy.stats import zscore
z = np.abs(zscore(test_df))
threshold = 3
test_df1 = test_df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", test_df.shape)
print ("Shape of the dataframe after removing outliers: ", test_df1.shape)
print ("Percentage of data loss post outlier removal: ", (test_df.shape[0]-test_df1.shape[0])/test_df.shape[0]*100)

test_df = test_df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (2645, 13)
# Shape of the dataframe after removing outliers:  (2624, 13)
# Percentage of data loss post outlier removal:  0.7939508506616257

# %%
test_df.skew()
# Out:
# Airline            0.478323
# Source            -0.426633
# Destination        0.791714
# Route             -0.271087
# Duration           0.826742
# Total_Stops        0.659810
# Additional_Info   -0.835966
# Journey_Day        0.474518
# Journey_Month      0.591529
# Dep_Hour           0.076868
# Dep_Min            0.134720
# Arrival_Hour      -0.436527
# Arrival_Min        0.106409
# dtype: float64

# %% [markdown]
# ### Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
test_df_scale = scaler.fit_transform(test_df)

# %% [markdown]
# ## Prediction on Test Dataset Using Final Model

# %%
# Loading the saved model
Model = joblib.load("Flight_Price_Final.pkl")

# %%
# Predicting the flight price from the features of the testing data
Predicted_Price_test = Model.predict(test_df_scale)
Predicted_Price_test

# Creating dataframe for Test data prediction
Prediction = pd.DataFrame()
Prediction['Price'] = Predicted_Price_test
Prediction
# Out:
#              Price
# 0     14750.722656
# 1      4690.046875
# 2     12601.854492
# 3     11737.973633
# 4      4854.763184
# ...            ...
# 2619  10028.969727
# 2620   5502.928711
# 2621  11281.769531
# 2622  13595.281250
# 2623   8985.549805
#
# [2624 rows x 1 columns]

# %% [markdown]
# **Writeing CSV file of Prediction**

# %%
# Saving the Predictions
Prediction.to_csv("Submission_Flight_Price_Data.csv",index=False)
