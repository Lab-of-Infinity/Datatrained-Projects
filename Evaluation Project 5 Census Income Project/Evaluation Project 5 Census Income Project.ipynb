# %% [markdown]
# ## <b> Evaluation Project 5 Census Income Project </b>
# <b><em> By: Mr.Lokesh Baviskar </em></b>
#
# <b><em> Batch: 1833 </em></b>

# %% [markdown]
# ###  <b> Problem Statement:</b>
# <b><em> This data was extracted from the 1994 Census bureau database by Ronny Kohavi and Barry Becker (Data Mining and Visualization, Silicon Graphics). A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1) && (HRSWK>0)). <u>The prediction task is to determine whether a person makes over $50K a year.</u></em></b>
#
# ### Description of fnlwgt (final weight)
#
# <b>The weights on the Current Population Survey (CPS) files are controlled to independent estimates of the civilian non-institutional population of the US. These are prepared monthly for us by Population Division here at the Census Bureau. We use 3 sets of controls. These are:
#
# 1. A single cell estimate of the population 16+ for each state.
#
# 2. Controls for Hispanic Origin by age and sex.
#
# 3. Controls by Race, age and sex.
#
# We use all three sets of controls in our weighting program and "rake" through them 6 times so that by the end we come back to all the controls we used. The term estimate refers to population totals derived from CPS by creating "weighted tallies" of any specified socio-economic characteristics of the population. People with similar demographic characteristics should have similar weights. There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.</b>

# %% [markdown]
# <b>To download the dataset, use the link given below.
#
# Downlaod Files:</b>
#
# https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv

# %% [markdown]
# - <b> Importing require library for performing EDA, Data Wrangling and data cleaning</b>

# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  Importing CSV file

# %%
df=pd.read_csv('census_income.csv')

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
df.head()
# Out:
# No of Rows: 32560
# No of Columns: 15
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %% [markdown]
# ####  Comment:
# <b> The Most columns names are self-explanatory remaining are explain below :</b>
# - Fnlwgt: sampling weight
# - Education_num: number of years of education in total
# - Capital_gain/Capital_loss: income from investment sources other than salary/wages

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
#  <b>  Before Going for Statistical exploration of data, first check integrity of data & Missing value </b>

# %% [markdown]
# ### Data Integrity Check

# %% [markdown]
# <b> Since dataset is large,  Let check for any entry which is repeated or duplicated in dataset. </b>

# %%
df.duplicated().sum() # This will check if any duplicate entry or duplicate row with same value exist
# Out:
# 24

# %% [markdown]
# <b> If we just check CSV File we can find that there are some missing value in dataset which shown fill with '?'
#
# Let check how many question mark (" ?") inside dataset.
# </b>

# %%
df.isin([' ?']).sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %% [markdown]
# <b> Let replace ' ?' with np.NaN </b>

# %%
df=df.replace(' ?',np.NaN)

# %% [markdown]
# <b> Let check if any whitespace, 'NA' or '-' exist in dataset. </b>

# %%
df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %% [markdown]
# #### Comment:
# 1. We have Replace ' ?' with np.NaN
# 2. No whitespace, NA, '-' exist in dataset.

# %% [markdown]
# <b> Let drop duplicated entry from dataset before checking null values. </b>

# %%
df.drop_duplicates(keep='last', inplace=True)

# %%
df.shape
# Out:
# (32536, 15)

# %% [markdown]
# ## Missing value check

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Comment:
# - There are missing values in Occupation,workclass, Native country.

# %%
#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                 Missing Values  % Missing data
# Occupation                1843        5.664495
# Workclass                 1836        5.642980
# Native_country             582        1.788788
# Income                       0        0.000000
# Hours_per_week               0        0.000000
# Capital_loss                 0        0.000000
# Capital_gain                 0        0.000000
# Sex                          0        0.000000
# Race                         0        0.000000
# Relationship                 0        0.000000
# Marital_status               0        0.000000
# Education_num                0        0.000000
# Education                    0        0.000000
# Fnlwgt                       0        0.000000
# Age                          0        0.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32536 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32536 non-null  int64
#  1   Workclass       30700 non-null  object
#  2   Fnlwgt          32536 non-null  int64
#  3   Education       32536 non-null  object
#  4   Education_num   32536 non-null  int64
#  5   Marital_status  32536 non-null  object
#  6   Occupation      30693 non-null  object
#  7   Relationship    32536 non-null  object
#  8   Race            32536 non-null  object
#  9   Sex             32536 non-null  object
#  10  Capital_gain    32536 non-null  int64
#  11  Capital_loss    32536 non-null  int64
#  12  Hours_per_week  32536 non-null  int64
#  13  Native_country  31954 non-null  object
#  14  Income          32536 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %% [markdown]
# #### Observation:
# - There are 32536 rows , 14 Independent columns and 1 Target feature.
# - Age,Fnlwgt, education_num, capital gain, capital loss, hours per week are Numerical variable and having int64 datatypes.
# - Work class, Education,Marital status, occupation, relationship, race,sex,native country are categorical feature with object datatypes.

# %%
# Separating numerical and categorical variable
Numerical=['Age','Fnlwgt','Education_num','Capital_gain','Capital_loss','Hours_per_week']
Category=['Workclass','Education','Marital_status','Occupation','Relationship','Race','Sex','Native_country','Income']

# %% [markdown]
# ## Missing value imputation

# %% [markdown]
# <b> Occupation, Workclass and Native Country are categorical variable so we can imputate them with mode of that feature.</b>

# %%
# Imputating Missing value with mode for categorical features
df['Occupation'].fillna(df['Occupation'].mode()[0],inplace=True)
df['Workclass'].fillna(df['Workclass'].mode()[0],inplace=True)
df['Native_country'].fillna(df['Native_country'].mode()[0],inplace=True)

# %% [markdown]
# ### Missing Value Check After Imputataion

# %%
#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                 Missing Values  % Missing data
# Income                       0             0.0
# Native_country               0             0.0
# Hours_per_week               0             0.0
# Capital_loss                 0             0.0
# Capital_gain                 0             0.0
# Sex                          0             0.0
# Race                         0             0.0
# Relationship                 0             0.0
# Occupation                   0             0.0
# Marital_status               0             0.0
# Education_num                0             0.0
# Education                    0             0.0
# Fnlwgt                       0             0.0
# Workclass                    0             0.0
# Age                          0             0.0

# %% [markdown]
# #### Comment :
# <b> Finally, No Missing Value is Present.
#
# We are Now Yes To Go Further !!!</b>

# %% [markdown]
# ### Statistical Matrix

# %%
# Visualizing the statistics of the columns using heatmap.
plt.figure(figsize=(12,8))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')
# Out:
# <AxesSubplot:>

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32536.0      38.585536      13.638193     17.0      28.0
# Fnlwgt          32536.0  189784.298992  105556.258211  12285.0  117831.5
# Education_num   32536.0      10.081725       2.571622      1.0       9.0
# Capital_gain    32536.0    1078.410069    7388.068465      0.0       0.0
# Capital_loss    32536.0      87.370912     403.107737      0.0       0.0
# Hours_per_week  32536.0      40.440343      12.347079      1.0      40.0
#
#                      50%        75%        max
# Age                 37.0      48.00       90.0
# Fnlwgt          178356.0  236993.25  1484705.0
# Education_num       10.0      12.00       16.0
# Capital_gain         0.0       0.00    99999.0
# Capital_loss         0.0       0.00     4356.0
# Hours_per_week      40.0      45.00       99.0

# %% [markdown]
# #### Observation:
# - The minimum and maximum age of people in the dataset is 19 and 90 years respectively, while the average age is 37.
# - The minimum and maximum years spent on education is 1 and 16 respectively, whereas the mean education level is 10 years.
# - While the minimum and average capital gain is 0, maximum is 99999. This seems odd, maybe some error within the data collection.
# - The number of hours spent per week varies between 1 to 99 and the average being 40 hours.

# %% [markdown]
# ### Start Exploring categorial features with Enlisting Value counts & Sub-categories

# %%
for i in Category:
    print(i)
    print(df[i].value_counts())
    print('='*100)
# Out:
# Workclass
#  Private             24509
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# ====================================================================================================
# Education
#  HS-grad         10494
#  Some-college     7282
#  Bachelors        5352
#  Masters          1722
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           645
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           332
#  1st-4th           166
#  Preschool          50
# Name: Education, dtype: int64
# ====================================================================================================
# Marital_status
#  Married-civ-spouse       14970
#  Never-married            10666
#  Divorced                  4441
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64
# ====================================================================================================
# Occupation
#  Prof-specialty       5979
#  Craft-repair         4094
#  Exec-managerial      4065
#  Adm-clerical         3767
#  Sales                3650
#  Other-service        3291
#  Machine-op-inspct    2000
#  Transport-moving     1597
#  Handlers-cleaners    1369
#  Farming-fishing       992
#  Tech-support          927
#  Protective-serv       649
#  Priv-house-serv       147
#  Armed-Forces            9
# Name: Occupation, dtype: int64
# ====================================================================================================
# Relationship
#  Husband           13187
#  Not-in-family      8291
#  Own-child          5064
#  Unmarried          3445
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64
# ====================================================================================================
# Race
#  White                 27794
#  Black                  3122
#  Asian-Pac-Islander     1038
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64
# ====================================================================================================
# Sex
#  Male      21774
#  Female    10762
# Name: Sex, dtype: int64
# ====================================================================================================
# Native_country
#  United-States                 29734
#  Mexico                          639
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Japan                            62
#  Guatemala                        62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  Greece                           29
#  France                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64
# ====================================================================================================
# Income
#  <=50K    24697
#  >50K      7839
# Name: Income, dtype: int64
# ====================================================================================================

# %% [markdown]
# # EDA

# %% [markdown]
# ### Start EDA by analysing our target variable first.

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(18,10))
df['Income'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Population Distribution', fontsize=22,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Income',data=df,ax=ax[1])
ax[1].set_title('Income Distribution',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Income",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Observation :
# - 75.9 % population (24697 peoples) have income less than 50K.
# - Our task is to predict income and we see that target variable income is imbalanced.
#
# <b> Let check each feature against Target variable to gain more insight into data before finding answer of important questions. </b>

# %% [markdown]
# ### Exploration of Age

# %%
print('Minimum Age:', df['Age'].min(),'years')
print('Maximum Age:', df['Age'].max(),'years')
print('Average Age:', df['Age'].mean(),'years')
# Out:
# Minimum Age: 17 years
# Maximum Age: 90 years
# Average Age: 38.58553602163757 years

# %%
# Defining function to create new columns to classify people according different age gruop
def age_group(x):
    x = int(x)
    x = abs(x)
    if (18 < x < 31):
        return "19-30"
    if (30 < x < 41) :
        return '31-40'
    if (40 < x <51):
        return '41-50'
    if (50 < x < 61):
        return "51-60"
    if (60 < x < 71):
        return "61-70"
    else :
        return 'Greater Than 70'

# %%
# Calling function age_group
df['age_group']=df['Age'].apply(age_group)

# %%
plt.figure(figsize=(12,6))
order_list = ['19-30','31-40','41-50','51-60','61-70','Greater Than 70']
p = sns.countplot(df['age_group'], hue=df['Income'], palette='hsv', order=order_list)
plt.title('Income of Individuals of Different Age Groups', fontsize=22, fontweight='bold')
p.set_xlabel('Age Groups')
plt.xticks(fontsize=16,fontweight ='bold')
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
# Distribution of age with income categories
ax= sns.FacetGrid(df,col='Income')
ax.map(sns.distplot,'Age')
plt.show()

# %% [markdown]
# #### Observation:
# <b> Here comes an interesting observation. We already know that only 24% people earnings more than 50K dollors and this plot tell us which age group then belong. </b>
# - almost 10 % people in age group of 19-30 earns more than 50 K dollars and this count drop even more in old peoples having age greater than 70.<b> Might be some lucky old ones has created good Retirement Plan compare to rest old peoples.</b>
# - We can find maximum people earning more than 50K dollors belong to age group 41-50 & 51-60. <u> It will be interesting to find out which profession lead this income to this category.</u>
#
# ### So let dive into workclass and see what insight we get from there.

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
df['Workclass'].value_counts().plot.pie(explode=[0,0.1,0.125,0.175,0.225,0.25,0.3,0.7],autopct='%2.1f%%',
                                          textprops ={ 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Workclass', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(df['Workclass'], hue=df['Income'], palette='hsv')
plt.title('Income distribution as per Workclass', fontsize=22, fontweight='bold')
p.set_xlabel('Workclass',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,fontweight ='bold',rotation=30)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
pd.crosstab(df['Income'],df["Workclass"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col0{
#             background-color:  #a1d066;
#             color:  #000000;
#         }#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col1{
#             background-color:  #6bb566;
#             color:  #000000;
#         }#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col2,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col7,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col0,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col1,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col2,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col3,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col4,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col5,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col6,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col7,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col8{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col3{
#             background-color:  #44a266;
#             color:  #000000;
#         }#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col4,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col0,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col1,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col2,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col3,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col5,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col6,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col7,#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col8{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col5{
#             background-color:  #66b266;
#             color:  #000000;
#         }#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col6{
#             background-color:  #5faf66;
#             color:  #000000;
#         }#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col8{
#             background-color:  #51a866;
#             color:  #000000;
#         }#T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col4{
#             background-color:  #cbe566;
#             color:  #000000;
#         }</style><table id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7" ><thead>    <tr>        <th class="index_name level0" >Workclass</th>        <th class="col_heading level0 col0" > Federal-gov</th>        <th class="col_heading level0 col1" > Local-gov</th>        <th class="col_heading level0 col2" > Never-worked</th>        <th class="col_heading level0 col3" > Private</th>        <th class="col_heading level0 col4" > Self-emp-inc</th>        <th class="col_heading level0 col5" > Self-emp-not-inc</th>        <th class="col_heading level0 col6" > State-gov</th>        <th class="col_heading level0 col7" > Without-pay</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level0" >Income</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7level0_row0" class="row_heading level0 row0" > <=50K</th>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col0" class="data row0 col0" >589</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col1" class="data row0 col1" >1476</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col2" class="data row0 col2" >7</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col3" class="data row0 col3" >19357</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col4" class="data row0 col4" >494</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col5" class="data row0 col5" >1816</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col6" class="data row0 col6" >944</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col7" class="data row0 col7" >14</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row0_col8" class="data row0 col8" >24697</td>
#             </tr>
#             <tr>
#                         <th id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7level0_row1" class="row_heading level0 row1" > >50K</th>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col0" class="data row1 col0" >371</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col1" class="data row1 col1" >617</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col3" class="data row1 col3" >5152</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col4" class="data row1 col4" >622</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col5" class="data row1 col5" >724</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col6" class="data row1 col6" >353</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row1_col8" class="data row1 col8" >7839</td>
#             </tr>
#             <tr>
#                         <th id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col0" class="data row2 col0" >960</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col1" class="data row2 col1" >2093</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col2" class="data row2 col2" >7</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col3" class="data row2 col3" >24509</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col4" class="data row2 col4" >1116</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col5" class="data row2 col5" >2540</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col6" class="data row2 col6" >1297</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col7" class="data row2 col7" >14</td>
#                         <td id="T_995d3dc1_3bd2_11ec_a5d6_e4029bad80b7row2_col8" class="data row2 col8" >32536</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Observation :
# - 75.3% people belongs to Private sector followed by Self Emplyoed not Incorporated with 7.8 %
# - <b><em>Interseting observation comes with <u> Self-Employed Incorporated </u> category where the number of people who earn more than 50K dollars exceed those earning less than it ! </em></b>
#
# - There is significant difference between private sector employees income where <u> less than 25 % people earn more than 50K dollars an year.</u>
# - Another quite surprising insight comes from Federal Goverment countplot where <b><em> We can see very minute difference between the number of people whose income is more or less than 50K dollars an year.</em></b> Same goes with state goverment with some difference.
#
# - Yes there exist category for who never worked and Working without pay but very few people belong to it.These people may be unempolyeed or colleges students. But Number is less And thats Good !!!
#
# <b><em>Certainly Goverment Emplyoees have high wages compare to private !!!</em></b>

# %% [markdown]
# ### Education Vs Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
df['Education'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Education', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(df['Education'], hue=df['Income'], palette='hsv')
plt.title('Income distribution as per Education', fontsize=22, fontweight='bold')
p.set_xlabel('Education',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,fontweight ='bold',rotation=30)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# #### Observation:
# - Out of all population 32.3% people with HS-Grad education which is most prevalent education level.
# - 5.3 % people with masters and 1.3 % population is Doctorate degree holder. Highly educated & intellactual people belongs to this category.
# - There are very handful people who earn more than 50 K dollars having education below 12th level.
# - Maximum number of people who earn more than 50K dollars are Bachelors degree holder.
# - <b> Here comes interesting observation about income of highly educated people. In case of people belonging to Masters, Doctorate and Prof-School category in the education level, the number people earning more than 50K dollars an year outnumber than the number of people earning less than it.</b>
# - In case of Assoc-acad or Assoc-voc, there are a few people who earn more than 50K dollars an year!

# %%
pd.crosstab(df['Education'],df["Workclass"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row0_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row2_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row2_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row2_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row2_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row2_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row3_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row3_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row4_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row5_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row10_col3{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row0_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row1_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row1_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row2_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row2_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row5_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row6_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row6_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row14_col1{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row0_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row15_col2{
#             background-color:  #b6db66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row0_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row7_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row7_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row7_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row14_col0{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row0_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row5_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row5_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row6_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row10_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row14_col8{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row0_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row0_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row1_col5{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row0_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row1_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row1_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row4_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row4_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row5_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row6_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row6_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row10_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row10_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row14_col3{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row0_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row1_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row2_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row2_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row3_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row3_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row3_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row3_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row3_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row3_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row3_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row4_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row4_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row4_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row4_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row4_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row4_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row5_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row6_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row6_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row6_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row6_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row7_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row8_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row8_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row9_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row9_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row10_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row10_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row12_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row12_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row13_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row13_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row13_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row13_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row13_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row13_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row13_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row13_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row13_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row14_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row14_col7{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row1_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row5_col2,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row11_col2{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row1_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row7_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row8_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row8_col1,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row8_col3,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row8_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row8_col8{
#             background-color:  #f5fa66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row1_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row7_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row7_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row8_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row8_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row10_col4{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row5_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row12_col3{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row5_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row7_col7,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row12_col4,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row14_col4{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row7_col0{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row9_col0,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row15_col8{
#             background-color:  #c7e366;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row9_col1{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row9_col3{
#             background-color:  #d9ec66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row9_col4{
#             background-color:  #c1e066;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row9_col5{
#             background-color:  #d7eb66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row9_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row11_col6{
#             background-color:  #cbe566;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row9_col8,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row12_col1{
#             background-color:  #d6eb66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row10_col5,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row14_col6{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row10_col6,#T_c3617ef6_3bdf_11ec_97a1_e4029bad80b7row12_col0{
#             background-co

# %%
# Percentage Income distribution in terms of Education
sns.set_palette('rainbow')
table = pd.crosstab(df['Education'], df['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,7))
plt.title('Percent Income distribution as per Education', fontsize=22, fontweight='bold')
plt.xlabel('Education', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %% [markdown]
# #### Observation:
# - In terms of percentage 75 % of Doctorate people earn more than 50K dollars an years, followed by Prof- school.
# - <b> So, Highly earning people most of times comes with Masters or Doctorate education background.</b>
# - From crosstab we can see that private sector is highest recuriter for HS-Grad with 8305 people.
# - Private sector is also major recurtier of highly eduacated people with masters, doctorate followed by local goverment.

# %% [markdown]
# ## Impact of Marital Status on Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set1')
plt.figure(figsize=(10,10))
df['Marital_status'].value_counts().plot.pie(autopct='%2.1f%%', explode=[0.075,0.1,0.125,0.15,0.175,0.2,0.225],
                                             textprops ={'fontsize':13,'fontweight':'bold'},shadow=True)
plt.title('Population distribution as per Marital Status', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
# Percentage Income distribution in terms of Education
sns.set_palette('rainbow')
table = pd.crosstab(df['Marital_status'], df['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(12,8))
plt.title('Percent Income distribution as per Marital Status', fontsize=22, fontweight='bold')
plt.xlabel('Marital Status', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %%
pd.crosstab(df['Marital_status'],df["Income"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_58d3a820_3be7_11ec_9941_e4029bad80b7row0_col0{
#             background-color:  #1d8e66;
#             color:  #000000;
#         }#T_58d3a820_3be7_11ec_9941_e4029bad80b7row0_col1{
#             background-color:  #c4e266;
#             color:  #000000;
#         }#T_58d3a820_3be7_11ec_9941_e4029bad80b7row0_col2{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_58d3a820_3be7_11ec_9941_e4029bad80b7row0_col3{
#             background-color:  #168b66;
#             color:  #000000;
#         }#T_58d3a820_3be7_11ec_9941_e4029bad80b7row0_col4{
#             background-color:  #0c8666;
#             color:  #000000;
#         }#T_58d3a820_3be7_11ec_9941_e4029bad80b7row0_col5{
#             background-color:  #118866;
#             color:  #000000;
#         }#T_58d3a820_3be7_11ec_9941_e4029bad80b7row0_col6{
#             background-color:  #178b66;
#             color:  #000000;
#         }#T_58d3a820_3be7_11ec_9941_e4029bad80b7row0_col7{
#             background-color:  #51a866;
#             color:  #000000;
#         }#T_58d3a820_3be7_11ec_9941_e4029bad80b7row1_col0,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row1_col1,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row1_col2,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row1_col3,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row1_col4,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row1_col5,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row1_col6,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row1_col7{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_58d3a820_3be7_11ec_9941_e4029bad80b7row2_col0,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row2_col1,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row2_col2,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row2_col3,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row2_col4,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row2_col5,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row2_col6,#T_58d3a820_3be7_11ec_9941_e4029bad80b7row2_col7{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_58d3a820_3be7_11ec_9941_e4029bad80b7" ><thead>    <tr>        <th class="index_name level0" >Marital_status</th>        <th class="col_heading level0 col0" > Divorced</th>        <th class="col_heading level0 col1" > Married-AF-spouse</th>        <th class="col_heading level0 col2" > Married-civ-spouse</th>        <th class="col_heading level0 col3" > Married-spouse-absent</th>        <th class="col_heading level0 col4" > Never-married</th>        <th class="col_heading level0 col5" > Separated</th>        <th class="col_heading level0 col6" > Widowed</th>        <th class="col_heading level0 col7" >All</th>    </tr>    <tr>        <th class="index_name level0" >Income</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T
# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
df['Occupation'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Occupation', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(df['Occupation'], hue=df['Income'], palette='cool')
plt.title('Income distribution as per Occupation', fontsize=22, fontweight='bold')
p.set_xlabel('Occupation',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,rotation=90)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# #### Observation :
# - Exec-managerial role are equally likely to earn more than 50K dollars an year.
# - Peoples working in Arm- Forces, Farming-fishing, Machine-op-inspect, Other-service, Adm-clerical, Handlers-cleaners are very less likely to earn more than 50K dollars an year.
# - Around 25% of the people working in Sales earn more than 50K dollars an year.

# %%
# Percentage Income distribution in terms of Education
sns.set_palette('rainbow')
table = pd.crosstab(df['Occupation'], df['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(12,8))
plt.title('Percent Income distribution as per Occupation', fontsize=22, fontweight='bold')
plt.xlabel('Occupation', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %%
pd.crosstab(df['Occupation'],df["Income"], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style  type="text/css" >
# #T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row0_col0{
#             background-color:  #00de90;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row0_col1{
#             background-color:  #00ef88;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row0_col2{
#             background-color:  #00e28e;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row1_col0,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row1_col1,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row1_col2,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row8_col1{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row2_col0,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row2_col2,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row7_col0,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row11_col1{
#             background-color:  #00df90;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row2_col1{
#             background-color:  #00e18e;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row3_col0{
#             background-color:  #00ea8a;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row3_col1{
#             background-color:  #00bfa0;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row3_col2{
#             background-color:  #00e08f;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row4_col0,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row12_col1{
#             background-color:  #00f684;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row4_col1{
#             background-color:  #00fc81;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row4_col2,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row12_col2{
#             background-color:  #00f883;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row5_col0,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row13_col0{
#             background-color:  #00f286;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row5_col1{
#             background-color:  #00fd80;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row5_col2,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row13_col1{
#             background-color:  #00f584;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row6_col0{
#             background-color:  #00ed88;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row6_col1{
#             background-color:  #00f784;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row6_col2{
#             background-color:  #00f087;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row7_col1,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row10_col0{
#             background-color:  #00fb82;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row7_col2{
#             background-color:  #00e68c;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row8_col0,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row8_col2{
#             background-color:  #00fe80;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row9_col0{
#             background-color:  #00d793;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row9_col1{
#             background-color:  #00bda0;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row9_col2{
#             background-color:  #00d196;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row10_col1,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row12_col0{
#             background-color:  #00f982;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row10_col2{
#             background-color:  #00fa82;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row11_col0{
#             background-color:  #00e48d;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row11_col2{
#             background-color:  #00e38e;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row13_col2{
#             background-color:  #00f386;
#             color:  #000000;
#         }#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row14_col0,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row14_col1,#T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row14_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7" ><thead>    <tr>        <th class="index_name level0" >Income</th>        <th class="col_heading level0 col0" > <=50K</th>        <th class="col_heading level0 col1" > >50K</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Occupation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7level0_row0" class="row_heading level0 row0" > Adm-clerical</th>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row0_col0" class="data row0 col0" >3260</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row0_col1" class="data row0 col1" >507</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row0_col2" class="data row0 col2" >3767</td>
#             </tr>
#             <tr>
#                         <th id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7level0_row1" class="row_heading level0 row1" > Armed-Forces</th>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row1_col0" class="data row1 col0" >8</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row1_col2" class="data row1 col2" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7level0_row2" class="row_heading level0 row2" > Craft-repair</th>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row2_col0" class="data row2 col0" >3165</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row2_col1" class="data row2 col1" >929</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row2_col2" class="data row2 col2" >4094</td>
#             </tr>
#             <tr>
#                         <th id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7level0_row3" class="row_heading level0 row3" > Exec-managerial</th>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row3_col0" class="data row3 col0" >2097</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row3_col1" class="data row3 col1" >1968</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row3_col2" class="data row3 col2" >4065</td>
#             </tr>
#             <tr>
#                         <th id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7level0_row4" class="row_heading level0 row4" > Farming-fishing</th>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row4_col0" class="data row4 col0" >877</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row4_col1" class="data row4 col1" >115</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row4_col2" class="data row4 col2" >992</td>
#             </tr>
#             <tr>
#                         <th id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7level0_row5" class="row_heading level0 row5" > Handlers-cleaners</th>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4029bad80b7row5_col0" class="data row5 col0" >1283</td>
#                         <td id="T_67f1e054_3bf3_11ec_af4d_e4

# %% [markdown]
# #### Observation :
# -  <b>Prof-Speciality position with maximum 2049 peoples followed by Exec-managerial position with 1968 people leads chart for greater than 50K dollars an year.</b>
# - If we talk in term of <b> percentage probablity Exective Managerial position have 50% chances to lead in Greater than 50K dollars Club.</b>
# - There's close to 33% probablity for an adult in Prof-specialty to earn more than 50K dollars an year.
# -<b> Minimum chances for Greater than 50K Club comes from Private House Service occupation </b> where 1/147 chance of getting more than 50K dollars an year.
#
# <b> Let check where these different occupation fit with respect to Work class through crosstab. </b>

# %%
pd.crosstab(df['Occupation'],df["Workclass"], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style  type="text/css" >
# #T_acd6776e_3bf3_11ec_9955_e4029bad80b7row0_col0{
#             background-color:  #00abaa;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row0_col1{
#             background-color:  #00dd90;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row0_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row1_col1,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row1_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row1_col3,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row1_col4,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row1_col5,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row1_col6,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row1_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row1_col8,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row2_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row3_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row3_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row4_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row5_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row5_col4,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row6_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row7_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row8_col0,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row8_col1,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row8_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row8_col4,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row8_col5,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row8_col6,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row8_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row9_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row10_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row10_col5,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row10_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row11_col1,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row11_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row11_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row12_col2,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row12_col4,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row12_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row13_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row0_col3,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row0_col8{
#             background-color:  #00e28e;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row0_col4,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row4_col8,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row10_col0,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row12_col3,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row12_col8{
#             background-color:  #00f883;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row0_col5,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row5_col1,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row10_col8{
#             background-color:  #00fa82;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row0_col6{
#             background-color:  #00ce98;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row0_col7{
#             background-color:  #00c99a;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row1_col0,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row4_col0,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row4_col6,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row6_col4,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row6_col6,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row11_col6,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row12_col5{
#             background-color:  #00fd80;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row2_col0,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row2_col1,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row7_col5{
#             background-color:  #00ee88;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row2_col3{
#             background-color:  #00de90;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row2_col4,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row7_col6{
#             background-color:  #00e78c;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row2_col5{
#             background-color:  #00ca9a;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row2_col6,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row4_col4,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row12_col6{
#             background-color:  #00f485;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row2_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row5_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row6_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row7_col7,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row12_col0,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row13_col7{
#             background-color:  #00ed88;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row2_col8{
#             background-color:  #00df90;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row3_col0{
#             background-color:  #00cf98;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row3_col1{
#             background-color:  #00e58c;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row3_col3,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row7_col3,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row11_col8{
#             background-color:  #00e38e;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row3_col4{
#             background-color:  #00a4ad;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row3_col5{
#             background-color:  #00d893;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row3_col6,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row9_col5,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row10_col1{
#             background-color:  #00da92;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row3_col8{
#             background-color:  #00e08f;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row4_col1,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row6_col0,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row6_col5,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row11_col0{
#             background-color:  #00fc81;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row4_col3,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row12_col1{
#             background-color:  #00fb82;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row4_col5,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row9_col3{
#             background-color:  #00d495;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row4_col7{
#             background-color:  #0092b6;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row5_col0,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row7_col4,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row13_col0,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row13_col4{
#             background-color:  #00f982;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row5_col3,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row13_col3{
#             background-color:  #00f286;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row5_col5,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row5_col6,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row6_col1,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row8_col3,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row8_col8,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row10_col3,#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row10_col4{
#             background-color:  #00fe80;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row5_col8{
#             background-color:  #00f584;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row6_col3{
#             background-color:  #00ec89;
#             color:  #000000;
#         }#T_acd6776e_3bf3_11ec_9955_e4029bad80b7row6_col8{
#             background-color:  #00f087;
#             color:  #000000;

# %% [markdown]
# #### Observation :
# - <b> Here is another surprising element, there are 7 peoples From Never Worked Category  with High earning Profession of Prof-speciality. Same from Without pay workclass we find 6 peoples with Exec-Managerial. Possibly they are working with unpaid internship profile.</b>

# %% [markdown]
# ### Relationship VS Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
df['Relationship'].value_counts().plot.pie(autopct='%2.1f%%',explode=[0.05,0.05,0.05,0.05,0.075,0.075],
                                           textprops ={'fontweight' :'bold', 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Relationship', fontsize=22,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
p = sns.countplot(df['Relationship'], hue=df['Income'], palette='cool')
plt.title('Income distribution as per Occupation', fontsize=22, fontweight='bold')
p.set_xlabel('Relationship',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,rotation=20)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# #### Observation:
# - Wives are equally likely to earn more than 50K dollars an year.
# - For Husbands, although significant, there is less possibility of them to earn more than 50K dollars an year.
# - There are just a handful of Unmarried people earning more than 50K dollars an year.

# %% [markdown]
# ### Race vs Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(10,10))
df['Race'].value_counts().plot.pie(autopct='%2.1f%%',explode=[0.05,0.05,0.05,0.05,0.075],
                                           textprops ={'fontweight' :'bold', 'fontsize':13}, shadow=True)
plt.title('Race distribution as per Relationship', fontsize=22,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
p = sns.countplot(df['Race'], hue=df['Income'], palette='cool')
plt.title('Race distribution as per Occupation', fontsize=22, fontweight='bold')
p.set_xlabel('Race',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,rotation=20)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
# Percentage Income distribution in terms of Education
sns.set_palette('viridis')
table = pd.crosstab(df['Race'], df['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(12,8))
plt.title('Percent Income distribution as per Race', fontsize=22, fontweight='bold')
plt.xlabel('Race', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %% [markdown]
# #### Observation:
# - 85.4 % peoples are whites followed by black community with 9.6%.
# - Maximum peoples in Greater than 50K Club are White.
# -<b> This observation is biased as we have very less data of other races. So Nothing Meaningful & reliable insight we can draw from it.</b>

# %% [markdown]
# ### Sex Vs Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('plasma')
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Sex'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Population Distribution', fontsize=22,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Sex',hue=df['Income'] ,data=df,ax=ax[1])
ax[1].set_title('Income Distribution',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Income",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Observation:
# - Significant gap between male and female earnings.
# - <b>Less than 10% Women in Greater Than 50K Dollar Club.</b>
# - Around 33% of Men earning more than 50K dollars an year.
#
# <b> Let find in which profession these women involved in . </b>

# %%
pd.crosstab(df['Occupation'],[df.Sex,df.Income], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style  type="text/css" >
# #T_58f40f0d_3c00_11ec_8566_e4029bad80b7row0_col0{
#             background-color:  #00c19e;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row0_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row7_col0,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row9_col4{
#             background-color:  #00d196;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row0_col2,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row6_col4{
#             background-color:  #00f087;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row0_col3,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row7_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row13_col3{
#             background-color:  #00f485;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row0_col4{
#             background-color:  #00e28e;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row1_col0,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row1_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row1_col2,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row1_col3,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row1_col4,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row4_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row5_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row8_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row8_col2,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row8_col3{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row2_col0,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row10_col4,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row12_col2{
#             background-color:  #00fa82;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row2_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row4_col3,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row5_col0,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row6_col1{
#             background-color:  #00fb82;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row2_col2{
#             background-color:  #00cd98;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row2_col3,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row11_col3{
#             background-color:  #00dd90;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row2_col4{
#             background-color:  #00df90;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row3_col0,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row7_col2{
#             background-color:  #00e88b;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row3_col1{
#             background-color:  #00c39e;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row3_col2,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row6_col2,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row13_col2{
#             background-color:  #00eb8a;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row3_col3{
#             background-color:  #00bfa0;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row3_col4,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row11_col0{
#             background-color:  #00e08f;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row4_col0,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row8_col4,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row10_col0,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row13_col1{
#             background-color:  #00fe80;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row4_col2{
#             background-color:  #00f286;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row4_col4,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row10_col3,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row12_col4{
#             background-color:  #00f883;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row5_col2{
#             background-color:  #00ed88;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row5_col3,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row7_col3,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row8_col0{
#             background-color:  #00fc81;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row5_col4{
#             background-color:  #00f584;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row6_col0{
#             background-color:  #00f186;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row6_col3,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row12_col0{
#             background-color:  #00f784;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row7_col4,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row11_col2{
#             background-color:  #00e68c;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row9_col0{
#             background-color:  #00cc99;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row9_col1{
#             background-color:  #00a1ae;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row9_col2{
#             background-color:  #00de90;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row9_col3{
#             background-color:  #00c29e;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row10_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row13_col0{
#             background-color:  #00fd80;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row10_col2{
#             background-color:  #00f982;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row11_col1{
#             background-color:  #00ec89;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row11_col4{
#             background-color:  #00e38e;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row12_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row12_col3{
#             background-color:  #00f684;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row13_col4{
#             background-color:  #00f386;
#             color:  #000000;
#         }#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row14_col0,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row14_col1,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row14_col2,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row14_col3,#T_58f40f0d_3c00_11ec_8566_e4029bad80b7row14_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_58f40f0d_3c00_11ec_8566_e4029bad80b7" ><thead>    <tr>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2> Female</th>        <th class="col_heading level0 col2" colspan=2> Male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="index_name level1" >Income</th>        <th class="col_heading level1 col0" > <=50K</th>        <th class="col_heading level1 col1" > >50K</th>        <th class="col_heading level1 col2" > <=50K</th>        <th class="col_heading level1 col3" > >50K</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Occupation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58f40f0d_3c00_11ec_8566_e4029bad80b7level0_row0" class="row_heading level0 row0" > Adm-clerical</th>
#                         <td id="T_58f40f0d_3c00_11ec_8566_e4029bad80b7row0_col0" class="data row0 col0" >2323</td>
#                         <td id="T_58f40f0d_3c00_11ec_8566_e4029bad80b7row0_col1" class="data row0 col1" >212</td>
#                         <td id="T_58f40f0d_3c00_11ec_8566_e4029bad80b7row0_col2" class="data row0 col2" >937</td>
#                         <td id=

# %% [markdown]
# #### Observation:
# - Out of all population 33 % are womens. Inside that most of females work in Adm-clerical,Other-service,Prof-specialty.
# - Same as in case of Men Maximum number in <u> Greater than 50K dollars Club in females comes from Prof-speciality,Exec-Managerial profession.</u>
# - Maximum men work in Prof-Specialty.

# %%
# Setting Parameters
plt.rcParams['figure.figsize'] = [15,15]
sns.set(style = 'darkgrid')

# This Violin plot show how capital gain, loss, hours per week and education vary with the race of the people
plt.subplot(2,2,1)
sns.violinplot(x = df['Race'], y = df['Capital_gain'], data = df);
plt.subplot(2,2,2)
sns.violinplot(x = df['Race'], y = df['Capital_loss'], data = df);
plt.subplot(2,2,3)
sns.violinplot(x = df['Race'], y = df['Hours_per_week'], data = df);
plt.subplot(2,2,4)
sns.violinplot(x = df['Race'], y = df['Education_num'], data = df);

# %%
# This shows the hours per week according to the education of the person
sns.set(rc={'figure.figsize':(12,8)})
sns_grad = sns.barplot(x = df['Education'], y = df['Hours_per_week'], data = df)
plt.setp(sns_grad.get_xticklabels(), rotation=90)
plt.show()

# %%
# Visualizing how the income changes for Native country of the people
plt.figure(figsize=(15,15))
plt.title("Income in each Native Country")
sns.pointplot(x='Native_country',y='Education_num',data=df, hue='Income',join=False,palette="Set2",ci="sd")
plt.xticks(rotation=90)
plt.show()

# %%
# Checking the pairwise relation in the dataset.
sns.pairplot(df,hue="Income",palette="husl")

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %% [markdown]
# # Encoding categorical data

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          5   83311          9             13               2
# 1   38          3  215646         11              9               0
# 2   53          3  234721          1              7               2
# 3   28          3  338409          9             13               2
# 4   37          3  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           3             0     4    1             0             0
# 1           5             1     4    1             0             0
# 2           5             0     2    1             0             0
# 3           9             5     2    0             0             0
# 4           3             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              13              38       0
# 1              40              38       0
# 2              40              38       0
# 3              40               4       0
# 4              40              38       0

# %% [markdown]
# # Feature selection and Engineering

# %% [markdown]
# ## 1. Outliers Detection and Removal

# %%
plt.figure(figsize=(18,10),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# <b> From Boxplot we can see outliers exist dataset.</b>

# %%
# Droping unnecessary columns
df.drop(["Fnlwgt", "Education"], axis=1, inplace=True)

# %% [markdown]
# ### Outliers removal using Zscore method

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (32536, 13)
# Shape of the dataframe after removing outliers:  (28061, 13)
# Percentage of data loss post outlier removal:  13.753995574133269

# %% [markdown]
# ##### Data Loss

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((32536-28061)/32536)*100,'%')
# Out:
# Percentage Data Loss : 13.753995574133269 %

# %% [markdown]
# <b><em> We are losing 13.75 % of data. Its big but we can afford it. Considering we have a lot of rows in our datatset for ML model building. We have option to go for quantile method but by looking at boxplot we can say lower capping will result in useful data loss and eventually data loss will be more than zscore method.</em></b>

# %% [markdown]
# ## 2.  Skewness of features

# %%
plt.figure(figsize=(22,5),facecolor='white')
plotnum=1
for col in df[['Age','Capital_gain','Capital_loss','Hours_per_week']]:
    if plotnum<=4:
        plt.subplot(1,4,plotnum)
        sns.distplot(df[col],color='r')
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
df.skew()
# Out:
# Age                0.487918
# Workclass          0.080746
# Education_num     -0.147601
# Marital_status    -0.046623
# Occupation         0.015247
# Relationship       0.752334
# Race              -2.549199
# Sex               -0.689977
# Capital_gain       4.924729
# Capital_loss      29.669292
# Hours_per_week    -0.359365
# Native_country    -5.348195
# Income             1.322011
# dtype: float64

# %% [markdown]
# #### Observation :
# - Relationship,Sex,Native_country,Income are skewed but as they are categorical concept of skewness doesnot mean anything to it.
# - Capital_gain and Capital_loss are numeric variable with lot of zero and high number. So skewness exist in them. There is no point in transforming it because at end data will be skewed.
#
# <b> We will have option of scaling data to handle skewness in Capital gain and Capital loss.</b>

# %% [markdown]
# ## 3. Corrleation

# %%
df.corr()
# Out:
#                      Age  Workclass  Education_num  Marital_status  \
# Age             1.000000   0.029674       0.045622       -0.286328
# Workclass       0.029674   1.000000      -0.002200       -0.015623
# Education_num   0.045622  -0.002200       1.000000       -0.058587
# Marital_status -0.286328  -0.015623      -0.058587        1.000000
# Occupation     -0.001610   0.008779       0.073142        0.036477
# Relationship   -0.270591  -0.057823      -0.092447        0.183248
# Race            0.021292   0.067532       0.080766       -0.084558
# Sex             0.089469   0.069617       0.003688       -0.125361
# Capital_gain    0.131998   0.011083       0.157858       -0.069601
# Capital_loss    0.023459  -0.010613       0.007348       -0.016396
# Hours_per_week  0.090783   0.028104       0.156303       -0.196053
# Native_country  0.037494   0.001938       0.149688       -0.032575
# Income          0.241844  -0.007699       0.320271       -0.194146
#
#                 Occupation  Relationship      Race       Sex  Capital_gain  \
# Age              -0.001610     -0.270591  0.021292  0.089469      0.131998
# Workclass         0.008779     -0.057823  0.067532  0.069617      0.011083
# Education_num     0.073142     -0.092447  0.080766  0.003688      0.157858
# Marital_status    0.036477      0.183248 -0.084558 -0.125361     -0.069601
# Occupation        1.000000     -0.038735  0.000613  0.051055      0.009446
# Relationship     -0.038735      1.000000 -0.146432 -0.577195     -0.089095
# Race              0.000613     -0.146432  1.000000  0.122731      0.031333
# Sex               0.051055     -0.577195  0.122731  1.000000      0.069539
# Capital_gain      0.009446     -0.089095  0.031333  0.069539      1.000000
# Capital_loss     -0.004779      0.030105  0.000186 -0.027323     -0.009077
# Hours_per_week   -0.022194     -0.261919  0.055486  0.236168      0.098705
# Native_country    0.018069     -0.011274  0.018660 -0.011189      0.019185
# Income            0.030664     -0.248263  0.094756  0.211792      0.343487
#
#                 Capital_loss  Hours_per_week  Native_country    Income
# Age                 0.023459        0.090783        0.037494  0.241844
# Workclass          -0.010613        0.028104        0.001938 -0.007699
# Education_num       0.007348        0.156303        0.149688  0.320271
# Marital_status     -0.016396       -0.196053       -0.032575 -0.194146
# Occupation         -0.004779       -0.022194        0.018069  0.030664
# Relationship        0.030105       -0.261919       -0.011274 -0.248263
# Race                0.000186        0.055486        0.018660  0.094756
# Sex                -0.027323        0.236168       -0.011189  0.211792
# Capital_gain       -0.009077        0.098705        0.019185  0.343487
# Capital_loss        1.000000       -0.003440        0.002925 -0.016465
# Hours_per_week     -0.003440        1.000000        0.004380  0.233472
# Native_country      0.002925        0.004380        1.000000  0.047240
# Income             -0.016465        0.233472        0.047240  1.000000

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df.corr()['Income'].drop(['Income']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Income',fontsize=15)
plt.title('Correlation of features with Target Variable Income',fontsize = 18)
plt.show()

# %% [markdown]
# #### Observation:
# - Capital loss and workclass,occupation, native country, race are correlated with target variable with less than 10% correlation. <b> After checking Mulitcollinearity we will decide to drop these poorly correlated features or go for PCA.
#
#     As high or low Correlation doesnot mean its causation !!!</b>
# - Between input features maximum correlation of -0.557 exist between sex and relationship.
# - Capital gain is highly correlated with target variable.

# %% [markdown]
#  ## 4. Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
vif['Features']= df.columns
vif
# Out:
#           VIF        Features
# 0   10.452897             Age
# 1    8.807425       Workclass
# 2   21.287850   Education_num
# 3    4.358505  Marital_status
# 4    3.357557      Occupation
# 5    2.937270    Relationship
# 6   36.291318            Race
# 7    4.566872             Sex
# 8    1.209589    Capital_gain
# 9    1.004295    Capital_loss
# 10  15.202917  Hours_per_week
# 11  79.077624  Native_country
# 12   1.777448          Income

# %% [markdown]
# #### Strategy to Address Multicollinearity :
# 1. Removing Some of highly correlated features. But this will not work here as most of input features are correlated with each other either moderated or poorly.
# 2. Another way to address Multicollinerity is to Scaled Data and then apply PCA.
#
# <b> We will go by Second way for further investigation. As For some Independent feature VIF is exceed permissible limit of 10.  </b>

# %% [markdown]
# ## 5. Balanceing Imbalanced target feature

# %%
df.Income.value_counts()
# Out:
# 0    21767
# 1     6294
# Name: Income, dtype: int64

# %% [markdown]
# <b> As Target variable data is Imbalanced in nature we will need to balance target variable.</b>

# %% [markdown]
# ### Balancing using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
# Splitting data in target and dependent feature
X = df.drop(['Income'], axis =1)
Y = df['Income']

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 1    21767
# 0    21767
# Name: Income, dtype: int64

# %% [markdown]
# <b><em> We have successfully resolved the class imbalanced problem and now all the categories have same data ensuring that the ML model does not get biased towards one category.</em></b>

# %% [markdown]
# ## Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %% [markdown]
# #### Comment -
# <b> AS per the graph, we can see that 9 principal components attribute for 90% of variation in the data.  We shall pick the first 9 components for our prediction. </b>

# %%
pca_new = PCA(n_components=9)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(9))

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (30473, 9)
# Training target vector size: (30473,)
# Test feature matrix size: (13061, 9)
# Test target vector size: (13061,)

# %% [markdown]
# ### Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.7770461679810122 on Random_state 28

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=28, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.7770461679810122
#
#
# Confusion matrix of Logistics Regression :
#  [[5022 1543]
#  [1369 5127]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.79      0.76      0.78      6565
#            1       0.77      0.79      0.78      6496
#
#     accuracy                           0.78     13061
#    macro avg       0.78      0.78      0.78     13061
# weighted avg       0.78      0.78      0.78     13061

# %% [markdown]
# ### Finding Optimal value of n_neighbors for KNN

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(12):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.39839275902661153
# RMSE value for k=  2 is: 0.42073215048845025
# RMSE value for k=  3 is: 0.3925849735896683
# RMSE value for k=  4 is: 0.4059129609955096
# RMSE value for k=  5 is: 0.3954027214760637
# RMSE value for k=  6 is: 0.3980082099417968
# RMSE value for k=  7 is: 0.3971416130772601
# RMSE value for k=  8 is: 0.39829665656253654
# RMSE value for k=  9 is: 0.39829665656253654
# RMSE value for k=  10 is: 0.39973576756152807
# RMSE value for k=  11 is: 0.40078783145618385
# RMSE value for k=  12 is: 0.40335853638388053

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(12), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# #### Comment-
# At k=3, we get the minimum RMSE value which approximately 0.3925849735896683, and shoots up on further increasing the k value. We can safely say that k=3 will give us the best result in this case

# %% [markdown]
# ## Applying other classification algorithm

# %%
model=[ LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]
        
for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('============================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix LogisticRegression() is
#
#
# Accuracy Score :
#  0.7770461679810122
#
#
# Confusion matrix :
#  [[5022 1543]
#  [1369 5127]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.79      0.76      0.78      6565
#            1       0.77      0.79      0.78      6496
#
#     accuracy                           0.78     13061
#    macro avg       0.78      0.78      0.78     13061
# weighted avg       0.78      0.78      0.78     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.8248219891279381
#
#
# Confusion matrix :
#  [[4907 1658]
#  [ 630 5866]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.75      0.81      6565
#            1       0.78      0.90      0.84      6496
#
#     accuracy                           0.82     13061
#    macro avg       0.83      0.83      0.82     13061
# weighted avg       0.83      0.82      0.82     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.7154888599647806
#
#
# Confusion matrix :
#  [[3770 2795]
#  [ 921 5575]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67      6565
#            1       0.67      0.86      0.75      6496
#
#     accuracy                           0.72     13061
#    macro avg       0.73      0.72      0.71     13061
# weighted avg       0.74      0.72      0.71     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.8143327463440778
#
#
# Confusion matrix :
#  [[5218 1347]
#  [1078 5418]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81      6565
#            1       0.80      0.83      0.82      6496
#
#     accuracy                           0.81     13061
#    macro avg       0.81      0.81      0.81     13061
# weighted avg       0.81      0.81      0.81     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix KNeighborsClassifier(n_neighbors=3) is
#
#
# Accuracy Score :
#  0.8458770385115995
#
#
# Confusion matrix :
#  [[5290 1275]
#  [ 738 5758]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84      6565
#            1       0.82      0.89      0.85      6496
#
#     accuracy                           0.85     13061
#    macro avg       0.85      0.85      0.85     13061
# weighted avg       0.85      0.85      0.85     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.8590460148533803
#
#
# Confusion matrix :
#  [[5491 1074]
#  [ 767 5729]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86      6565
#            1       0.84      0.88      0.86      6496
#
#     accuracy                           0.86     13061
#    macro avg       0.86      0.86      0.86     13061
# weighted avg       0.86      0.86      0.86     13061
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix ExtraTreesClassifier() is
#
#
# Accuracy Score :
#  0.8585100681417962
#
#
# Confusion matrix :
#  [[5538 1027]
#  [ 821 5675]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86      6565
#            1       0.85      0.87      0.86      6496
#
#     accuracy                           0.86     13061
#    macro avg       0.86      0.86      0.86     13061
# weighted avg       0.86      0.86      0.86     13061
#
#
#
# ============================================================================================================

# %% [markdown]
# # CrossValidation :

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, principle_x, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('============================================================================================================')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.76088205 0.7658206  0.76019295 0.77822442 0.77486791]
# Mean Score : 0.7679975851132925
# Std deviation : 0.0073221837927897465
#
#
# ============================================================================================================
#
#
# Cross Validation Score SVC() :
#
# Score : [0.81313885 0.82094866 0.82267141 0.83254852 0.83275902]
# Mean Score : 0.824413294108574
# Std deviation : 0.007456324590903305
#
#
# ============================================================================================================
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.70322729 0.71873205 0.7181578  0.7183875  0.72685504]
# Mean Score : 0.717071938785862
# Std deviation : 0.00765570720027397
#
#
# ============================================================================================================
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.79166188 0.81727346 0.82864362 0.83587918 0.83275902]
# Mean Score : 0.8212434307802174
# Std deviation : 0.016077346578997315
#
#
# ============================================================================================================
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=3) :
#
# Score : [0.81463191 0.83966923 0.85138394 0.8593086  0.8550425 ]
# Mean Score : 0.8440072365338102
# Std deviation : 0.01607515474683319
#
#
# ============================================================================================================
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.82852877 0.85230274 0.86482141 0.87309062 0.87261659]
# Mean Score : 0.8582720251886128
# Std deviation : 0.016664603463484952
#
#
# ============================================================================================================
#
#
# Cross Validation Score ExtraTreesClassifier() :
#
# Score : [0.83162972 0.8544849  0.86826691 0.87320547 0.87204227]
# Mean Score : 0.8599258537330814
# Std deviation : 0.0156397181489822
#
#
# ============================================================================================================

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
              'min_samples_split':[3,5,8],
              'max_depth' : [20,30,40],
              'n_estimators' : [100, 150, 200]
             }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 1/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.849 total time=   4.6s
# [CV 2/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 2/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.844 total time=   3.5s
# [CV 3/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 3/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.857 total time=   3.1s
# [CV 4/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 4/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.853 total time=   3.3s
# [CV 5/5; 1/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100
# [CV 5/5; 1/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.846 total time=   2.9s
# [CV 1/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 1/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.846 total time=   4.6s
# [CV 2/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 2/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.844 total time=   5.3s
# [CV 3/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 3/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.853 total time=   6.1s
# [CV 4/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 4/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.853 total time=   4.3s
# [CV 5/5; 2/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150
# [CV 5/5; 2/54] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.846 total time=   4.9s
# [CV 1/5; 3/54] START criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200
# [CV
54] START criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200
# [CV 5/5; 48/54] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.851 total time=   8.6s
# [CV 1/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 1/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.852 total time=   4.6s
# [CV 2/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 2/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.850 total time=   5.9s
# [CV 3/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 3/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.858 total time=   4.9s
# [CV 4/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 4/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.852 total time=   4.4s
# [CV 5/5; 49/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100
# [CV 5/5; 49/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.846 total time=   5.0s
# [CV 1/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 1/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.852 total time=   8.0s
# [CV 2/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 2/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.850 total time=   6.9s
# [CV 3/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 3/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.860 total time=   6.4s
# [CV 4/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 4/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.851 total time=   6.4s
# [CV 5/5; 50/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150
# [CV 5/5; 50/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.852 total time=   6.1s
# [CV 1/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 1/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.853 total time=  10.1s
# [CV 2/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 2/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.850 total time=   9.1s
# [CV 3/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 3/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.860 total time=   9.2s
# [CV 4/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 4/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.851 total time=   8.2s
# [CV 5/5; 51/54] START criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200
# [CV 5/5; 51/54] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.851 total time=   8.1s
# [CV 1/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 1/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.853 total time=   3.8s
# [CV 2/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 2/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.850 total time=   3.8s
# [CV 3/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 3/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.860 total time=   3.6s
# [CV 4/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 4/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.855 total time=   4.0s
# [CV 5/5; 52/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100
# [CV 5/5; 52/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.851 total time=   4.2s
# [CV 1/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 1/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.852 total time=   5.5s
# [CV 2/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 2/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.853 total time=   5.5s
# [CV 3/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 3/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.860 total time=   6.8s
# [CV 4/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 4/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.854 total time=   6.3s
# [CV 5/5; 53/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150
# [CV 5/5; 53/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.850 total time=   7.2s
# [CV 1/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 1/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.854 total time=   9.7s
# [CV 2/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 2/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.851 total time=  11.5s
# [CV 3/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 3/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.859 total time=  10.7s
# [CV 4/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 4/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.851 total time=  10.9s
# [CV 5/5; 54/54] START criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200
# [CV 5/5; 54/54] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.852 total time=  10.8s
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [20, 30, 40],
#                          'min_samples_split': [3, 5, 8],
#                          'n_estimators': [100, 150, 200]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 30,
#  'min_samples_split': 8,
#  'n_estimators': 200}

# %% [markdown]
# # Final Model

# %%
Final_mod = ExtraTreesClassifier(criterion='entropy',n_estimators= 200, max_depth=30 ,min_samples_split= 8)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.8614194931475385

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(Final_mod,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.figure(figsize=(10,10))
plt.show()
plt.show()
auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.8615895563125846

# %% [markdown]
# ## Saving model

# %%
import joblib
joblib.dump(Final_mod,'Census_Income_Final.pkl')
# Out:
# ['Census_Income_Final.pkl']
